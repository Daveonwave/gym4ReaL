# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %cd ../..
# Out:
# /Users/dave/Library/CloudStorage/OneDrive-PolitecnicodiMilano/PhD/Repositories/gym4ReaL

# %%
import wntr

# %%
wn = wntr.network.WaterNetworkModel('gym4real/data/wds/towns/anytown_map.inp')
# Out:
# /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages/wntr/epanet/io.py:2082: UserWarning: Not all curves were used in "gym4real/data/wds/towns/anytown_map.inp"; added with type None, units conversion left to user
#   warnings.warn('Not all curves were used in "{}"; added with type None, units conversion left to user'.format(self.wn.name))

# %%
wn.describe(level=1)
# Out:
# {'Nodes': {'Junctions': 22, 'Tanks': 2, 'Reservoirs': 1},
#  'Links': {'Pipes': 43, 'Pumps': 2, 'Valves': 0},
#  'Patterns': 2,
#  'Curves': {'Pump': 1, 'Efficiency': 0, 'Headloss': 0, 'Volume': 0},
#  'Sources': 0,
#  'Controls': 0}

# %%
# Plot a basic network graphic
ax = wntr.graphics.plot_network(wn)
