# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %cd ../..
# Out:
# /Users/dave/Library/CloudStorage/OneDrive-PolitecnicodiMilano/PhD/Repositories/gym4ReaL

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import OrderedDict, defaultdict
import gymnasium as gym
import json

# %%
sns.set_theme()
sns.set_style('whitegrid')
sns.set_context("paper")
plot_colors = sns.color_palette('colorblind')
sns.set(font_scale=1.2)

alg_color = OrderedDict({
    'random': plot_colors[1],
    'longest_first': plot_colors[2],
    'shortest_first': plot_colors[3],
    'q-learning': plot_colors[0],
    'sarsa': plot_colors[4],
    'dqn': plot_colors[5],
    'ppo': plot_colors[6],
    'fqi': plot_colors[7]
})

alg_markers = OrderedDict({
    'random': '.',
    'longest_first': 'o',
    'shortest_first': 's',
    'q-learning': 's',
    'sarsa': 's',
})

alg_labels = {
    'random': 'Random',
    'longest_first': 'LF',
    'shortest_first': 'SF',
    'q-learning': 'Q-Learning',
    'sarsa': 'SARSA',
    'dqn': 'DQN',
    'ppo': 'PPO',
    'fqi': 'FQI'
}

# %%
res = {}

with open('examples/elevator/eval_results/qlearning.json', 'r') as f:
    res['q-learning'] = json.load(f)

with open('examples/elevator/eval_results/sarsa.json', 'r') as f:
    res['sarsa'] = json.load(f)

# %%
res['sarsa'] = {key : res['sarsa'][key] for key in res['q-learning'].keys()}

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 3.5), tight_layout=True)

for i, alg in enumerate(res.keys()):
    means = np.mean(list(res[alg].values()), axis=1)
    stds = np.std(list(res[alg].values()), axis=1)
    ci = 1.96 * stds / np.sqrt(len(res[alg].keys()))
    
    ax.plot(means, label=alg_labels[alg], color=alg_color[alg])
    ax.fill_between(range(len(means)), means + ci, means - ci, color=alg_color[alg], alpha=0.1)
    
    # Set axis labels
    ax.set_xlabel("Learning epochs")
    ax.set_ylabel("Global waiting time (s)")

# Set scientific notation for y-axis
ax.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))

# Add legend
ax.legend()

# Save figure
plt.savefig('plots/elevator_curves.pdf')
