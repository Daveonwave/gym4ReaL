# %% [markdown]
# # Tutorial for `mlcroissant` 🥐

# %% [markdown]
# ## Introduction
#
# Croissant 🥐 is a high-level format for machine learning datasets that combines metadata, resource file descriptions, data structure, and default ML semantics into a single file.
#
# Croissant builds on schema.org, and its `sc:Dataset` vocabulary, a widely used format to represent datasets on the Web, and make them searchable.
#
# The [`mlcroissant`](https://github.com/mlcommons/croissant/python/mlcroissant) Python library empowers developers to interact with Croissant:
#
# - Programmatically write your JSON-LD Croissant files.
# - Verify your JSON-LD Croissant files.
# - Load data from Croissant datasets.

# %%
# # Install mlcroissant from the source
# !brew install -y python3-dev graphviz libgraphviz-dev pkg-config
# !pip install "git+https://github.com/${GITHUB_REPOSITORY:-mlcommons/croissant}.git@${GITHUB_HEAD_REF:-main}#subdirectory=python/mlcroissant&egg=mlcroissant[dev]"

# %%
import mlcroissant as mlc
import hashlib
import json

# %% [markdown]
# When creating `Metadata`:
# - We also check for errors in the configuration.
# - We generate warnings if the configuration doesn't follow guidelines and best practices.
#
# For instance, in this case:

# %% [markdown]
# `Property "https://schema.org/license" is recommended`...
#
# We can see at a glance that we miss an important metadata to build datasets for responsible AI: the license!

# %% [markdown]
# ## Build the Croissant file and yield data
#
# Let's write the Croissant JSON-LD to a file on disk!

# %% [markdown]
# From this JSON-LD file, we can easily create a dataset...

# %% [markdown]
# ...and yield records from this dataset:

# %%
# DEMAND
mef = "gym4real/data/dam/MEF.csv"
demand_train = 'gym4real/data/dam/demand/demand_train.csv'
demand_test = 'gym4real/data/dam/demand/demand_test.csv'
inflow_train = 'gym4real/data/dam/inflow/inflow_train.csv'
inflow_test = 'gym4real/data/dam/inflow/inflow_test.csv'

with open(mef, "rb") as f:
    sha256_hash_mef = hashlib.sha256(f.read()).hexdigest()

with open(demand_train, "rb") as f:
    sha256_hash_demand_train = hashlib.sha256(f.read()).hexdigest()
with open(demand_test, "rb") as f:
    sha256_hash_demand_test = hashlib.sha256(f.read()).hexdigest()

with open(inflow_train, "rb") as f:
    sha256_hash_inflow_train = hashlib.sha256(f.read()).hexdigest()
with open(inflow_test, "rb") as f:
    sha256_hash_inflow_test = hashlib.sha256(f.read()).hexdigest()


# FileObjects and FileSets define the resources of the dataset.
distribution = [
    mlc.FileObject(
        id="demand_train",
        name="demand_train",
        description="Train water demand",
        content_url="https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/" + demand_train,
        encoding_formats=["text/csv"],
        sha256=sha256_hash_demand_train,
    ),
    mlc.FileObject(
        id="demand_test",
        name="demand_test",
        description="Test water demand",
        content_url="https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/" + demand_test,
        encoding_formats=["text/csv"],
        sha256=sha256_hash_demand_test,
    ),

    mlc.FileObject(
        id="inflow_train",
        name="inflow_train",
        description="Train water inflow",
        content_url="https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/" + inflow_train,
        encoding_formats=["text/csv"],
        sha256=sha256_hash_inflow_train,
    ),
    mlc.FileObject(
        id="inflow_test",
        name="inflow_test",
        description="Test water inflow",
        content_url="https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/" + inflow_test,
        encoding_formats=["text/csv"],
        sha256=sha256_hash_inflow_test,
    ),

    mlc.FileObject(
        id="mef_file_object",
        name="min_env_flow",
        description="Minimum amount of water to release",
        content_url="https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/" + mef,
        encoding_formats=["text/csv"],
        sha256=sha256_hash_mef,
    ),
]


train_demand_fields = [
    mlc.Field(
        id="year_demand_train",
        name="year",
        description="The year that the data was collected in",
        data_types=mlc.DataType.INTEGER,
        source=mlc.Source(
                    file_object="demand_train",
                    # file_object='github-repository',
                    # Extract the field from the column of a FileObject/FileSet:
                    extract=mlc.Extract(column="year"),
                ),
    )
]

for i in range(366):
    train_demand_fields.append(
        mlc.Field(
            id=str(i) + '_demand_train',
            name=str(i),
            description=f"The data regarding day {i}",
            data_types=mlc.DataType.FLOAT,
            source=mlc.Source(
                        file_object="demand_train",
                        # file_object='github-repository',
                        # Extract the field from the column of a FileObject/FileSet:
                        extract=mlc.Extract(column=str(i)),
                    ),
        )
    )

test_demand_fields = [
    mlc.Field(
        id="year_demand_test",
        name="year",
        description="The year that the data was collected in",
        data_types=mlc.DataType.INTEGER,
        source=mlc.Source(
                    file_object="demand_test",
                    # file_object='github-repository',
                    # Extract the field from the column of a FileObject/FileSet:
                    extract=mlc.Extract(column="year"),
                ),
    )
]

for i in range(366):
    test_demand_fields.append(
        mlc.Field(
            id=str(i) + '_demand_test',
            name=str(i),
            description=f"The data regarding day {i}",
            data_types=mlc.DataType.FLOAT,
            source=mlc.Source(
                        file_object="demand_test",
                        # file_object='github-repository',
                        # Extract the field from the column of a FileObject/FileSet:
                        extract=mlc.Extract(column=str(i)),
                    ),
        )
    )



train_inflow_fields = [
    mlc.Field(
        id="year_inflow_train",
        name="year",
        description="The year that the data was collected in",
        data_types=mlc.DataType.INTEGER,
        source=mlc.Source(
                    file_object="inflow_train",
                    # file_object='github-repository',
                    # Extract the field from the column of a FileObject/FileSet:
                    extract=mlc.Extract(column="year"),
                ),
    )
]

for i in range(366):
    train_inflow_fields.append(
        mlc.Field(
            id=str(i) + '_inflow_train',
            name=str(i),
            description=f"The data regarding day {i}",
            data_types=mlc.DataType.FLOAT,
            source=mlc.Source(
                        file_object="inflow_train",
                        # file_object='github-repository',
                        # Extract the field from the column of a FileObject/FileSet:
                        extract=mlc.Extract(column=str(i)),
                    ),
        )
    )

test_inflow_fields = [
    mlc.Field(
        id="year_inflow_test",
        name="year",
        description="The year that the data was collected in",
        data_types=mlc.DataType.INTEGER,
        source=mlc.Source(
                    file_object="inflow_test",
                    # file_object='github-repository',
                    # Extract the field from the column of a FileObject/FileSet:
                    extract=mlc.Extract(column="year"),
                ),
    )
]

for i in range(366):
    test_inflow_fields.append(
        mlc.Field(
            id=str(i) + '_inflow_test',
            name=str(i),
            description=f"The data regarding day {i}",
            data_types=mlc.DataType.FLOAT,
            source=mlc.Source(
                        file_object="inflow_test",
                        # file_object='github-repository',
                        # Extract the field from the column of a FileObject/FileSet:
                        extract=mlc.Extract(column=str(i)),
                    ),
        )
    )

mef_fields = [
    mlc.Field(
        id="MEF",
        name="MEF",
        description="The year that the data was collected in",
        data_types=mlc.DataType.FLOAT,
        source=mlc.Source(
                    file_object="mef_file_object",
                    # file_object='github-repository',
                    # Extract the field from the column of a FileObject/FileSet:
                    extract=mlc.Extract(column="MEF"),
                ),
    )
]


# ---------------------------

record_sets = [
    # RecordSets contains records in the dataset.
    mlc.RecordSet(
        id="demand_train_table",
        name="demand_train_table",
        # Each record has one or many fields...
        fields=train_demand_fields,
    ),
    mlc.RecordSet(
        id="demand_test_table",
        name="demand_test_table",
        # Each record has one or many fields...
        fields=test_demand_fields,
    ),
    mlc.RecordSet(
        id="inflow_train_table",
        name="inflow_train_table",
        # Each record has one or many fields...
        fields=train_inflow_fields,
    ),
    mlc.RecordSet(
        id="inflow_test_table",
        name="inflow_test_table",
        # Each record has one or many fields...
        fields=test_inflow_fields,
    ),
    mlc.RecordSet(
        id="mef_table",
        name="mef_table",
        # Each record has one or many fields...
        fields=mef_fields,
    ),

]

# Metadata contains information about the dataset.
metadata = mlc.Metadata(
    name="dam_data",
    # Descriptions can contain plain text or markdown.
    description=(
        "Data of water demand, inflow and minimum daily release"
    ),
    # cite_as=(
    #     "@article{brown2020language, title={Language Models are Few-Shot"
    # ),
    url="https://github.com/Daveonwave/gym4ReaL",
    license="https://creativecommons.org/licenses/by/4.0/",
    distribution=distribution,
    record_sets=record_sets,
)

# %%
print(metadata.issues.report())
# Out:
# Found the following 3 warning(s) during the validation:
#   -  [Metadata(dam_data)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
#   -  [Metadata(dam_data)] Property "https://schema.org/datePublished" is recommended, but does not exist.
#   -  [Metadata(dam_data)] Property "https://schema.org/version" is recommended, but does not exist.

# %%
with open("metadata_dam.json", "w") as f:
  content = metadata.to_json()
  content = json.dumps(content, indent=2)
  print(content)
  f.write(content)
  f.write("\n")  # Terminate file with newline
# Out:
# {
#   "@context": {
#     "@language": "en",
#     "@vocab": "https://schema.org/",
#     "citeAs": "cr:citeAs",
#     "column": "cr:column",
#     "conformsTo": "dct:conformsTo",
#     "cr": "http://mlcommons.org/croissant/",
#     "rai": "http://mlcommons.org/croissant/RAI/",
#     "data": {
#       "@id": "cr:data",
#       "@type": "@json"
#     },
#     "dataType": {
#       "@id": "cr:dataType",
#       "@type": "@vocab"
#     },
#     "dct": "http://purl.org/dc/terms/",
#     "examples": {
#       "@id": "cr:examples",
#       "@type": "@json"
#     },
#     "extract": "cr:extract",
#     "field": "cr:field",
#     "fileProperty": "cr:fileProperty",
#     "fileObject": "cr:fileObject",
#     "fileSet": "cr:fileSet",
#     "format": "cr:format",
#     "includes": "cr:includes",
#     "isLiveDataset": "cr:isLiveDataset",
#     "jsonPath": "cr:jsonPath",
#     "key": "cr:key",
#     "md5": "cr:md5",
#     "parentField": "cr:parentField",
#     "path": "cr:path",
#     "recordSet": "cr:recordSet",
#     "references": "cr:references",
#     "regex": "cr:regex",
#     "repeated": "cr:repeated",
#     "replace": "cr:replace",
#     "sc": "https://schema.org/",
#     "separator": "cr:separator",
#     "source": "cr:source",
#     "subField": "cr:subField",
#     "transform": "cr:transform"
#   },
#   "@type": "sc:Dataset",
#   "name": "dam_data",
#   "description": "Data of water demand, inflow and minimum daily release",
#   "conformsTo": "http://mlcommons.org/croissant/1.0",
#   "license": "https://creativecommons.org/licenses/by/4.0/",
#   "url": "https://github.com/Daveonwave/gym4ReaL",
#   "distribution": [
#     {
#       "@type": "cr:FileObject",
#       "@id": "demand_train",
#       "name": "demand_train",
#       "description": "Train water demand",
#       "contentUrl": "https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/gym4real/data/dam/demand/demand_train.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "ae1e18c0a5aeb384c3af1c14b9c6e7916872e56166bb0c519531088ee96f70f3"
#     },
#     {
#       "@type": "cr:FileObject",
#       "@id": "demand_test",
#       "name": "demand_test",
#       "description": "Test water demand",
#       "contentUrl": "https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/gym4real/data/dam/demand/demand_test.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "146f775660a571a9b4159f799f90d173036862356a4c8c12932039e2b59c7e5a"
#     },
#     {
#       "@type": "cr:FileObject",
#       "@id": "inflow_train",
#       "name": "inflow_train",
#       "description": "Train water inflow",
#       "contentUrl": "https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/gym4real/data/dam/inflow/inflow_train.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "f414467ee73e0f44fc6d2f72b67136cd943559a9ab566208a8887bf2df77b246"
#     },
#     {
#       "@type": "cr:FileObject",
#       "@id": "inflow_test",
#       "name": "inflow_test",
#       "description": "Test water inflow",
#       "contentUrl": "https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/gym4real/data/dam/inflow/inflow_test.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "8f92de2f40faf0c821d26858abb1bb157f7ebaee649ab6cbd31b132a9ab5b81f"
#     },
#     {
#       "@type": "cr:FileObject",
#       "@id": "mef_file_object",
#       "name": "min_env_flow",
#       "description": "Minimum amount of water to release",
#       "contentUrl": "https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/gym4real/data/dam/MEF.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "3fc243fb75e481aae48dfce95a2608c6f990af6928b1282d6d8fee41300ade99"
#     }
#   ],
#   "recordSet": [
#     {
#       "@type": "cr:RecordSet",
#       "@id": "demand_train_table",
#       "name": "demand_train_table",
#       "field": [
#         {
#           "@type": "cr:Field",
#           "@id": "year_demand_train",
#           "name": "year",
#           "description": "The year that the data was collected in",
#           "dataType": "sc:Integer",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "year"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "0_demand_train",
#           "name": "0",
#           "description": "The data regarding day 0",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "0"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "1_demand_train",
#           "name": "1",
#           "description": "The data regarding day 1",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "1"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "2_demand_train",
#           "name": "2",
#           "description": "The data regarding day 2",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "2"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "3_demand_train",
#           "name": "3",
#           "description": "The data regarding day 3",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "3"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "4_demand_train",
#           "name": "4",
#           "description": "The data regarding day 4",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "4"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "5_demand_train",
#           "name": "5",
#           "description": "The data regarding day 5",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "5"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "6_demand_train",
#           "name": "6",
#           "description": "The data regarding day 6",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "6"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "7_demand_train",
#           "name": "7",
#           "description": "The data regarding day 7",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "7"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "8_demand_train",
#           "name": "8",
#           "description": "The data regarding day 8",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "8"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "9_demand_train",
#           "name": "9",
#           "description": "The data regarding day 9",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "9"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "10_demand_train",
#           "name": "10",
#           "description": "The data regarding day 10",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "10"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "11_demand_train",
#           "name": "11",
#           "description": "The data regarding day 11",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "11"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "12_demand_train",
#           "name": "12",
#           "description": "The data regarding day 12",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "12"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "13_demand_train",
#           "name": "13",
#           "description": "The data regarding day 13",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "13"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "14_demand_train",
#           "name": "14",
#           "description": "The data regarding day 14",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "14"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "15_demand_train",
#           "name": "15",
#           "description": "The data regarding day 15",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "15"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "16_demand_train",
#           "name": "16",
#           "description": "The data regarding day 16",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "16"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "17_demand_train",
#           "name": "17",
#           "description": "The data regarding day 17",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "17"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "18_demand_train",
#           "name": "18",
#           "description": "The data regarding day 18",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "18"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "19_demand_train",
#           "name": "19",
#           "description": "The data regarding day 19",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "19"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "20_demand_train",
#           "name": "20",
#           "description": "The data regarding day 20",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "20"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "21_demand_train",
#           "name": "21",
#           "description": "The data regarding day 21",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "21"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "22_demand_train",
#           "name": "22",
#           "description": "The data regarding day 22",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "22"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "23_demand_train",
#           "name": "23",
#           "description": "The data regarding day 23",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "23"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "24_demand_train",
#           "name": "24",
#           "description": "The data regarding day 24",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "24"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "25_demand_train",
#           "name": "25",
#           "description": "The data regarding day 25",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "25"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "26_demand_train",
#           "name": "26",
#           "description": "The data regarding day 26",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "26"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "27_demand_train",
#           "name": "27",
#           "description": "The data regarding day 27",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "27"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "28_demand_train",
#           "name": "28",
#           "description": "The data regarding day 28",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "28"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "29_demand_train",
#           "name": "29",
#           "description": "The data regarding day 29",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "29"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "30_demand_train",
#           "name": "30",
#           "description": "The data regarding day 30",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "30"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "31_demand_train",
#           "name": "31",
#           "description": "The data regarding day 31",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "31"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "32_demand_train",
#           "name": "32",
#           "description": "The data regarding day 32",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "32"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "33_demand_train",
#           "name": "33",
#           "description": "The data regarding day 33",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "33"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "34_demand_train",
#           "name": "34",
#           "description": "The data regarding day 34",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "34"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "35_demand_train",
#           "name": "35",
#           "description": "The data regarding day 35",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "35"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "36_demand_train",
#           "name": "36",
#           "description": "The data regarding day 36",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "36"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "37_demand_train",
#           "name": "37",
#           "description": "The data regarding day 37",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "37"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "38_demand_train",
#           "name": "38",
#           "description": "The data regarding day 38",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "38"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "39_demand_train",
#           "name": "39",
#           "description": "The data regarding day 39",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "39"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "40_demand_train",
#           "name": "40",
#           "description": "The data regarding day 40",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "40"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "41_demand_train",
#           "name": "41",
#           "description": "The data regarding day 41",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "41"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "42_demand_train",
#           "name": "42",
#           "description": "The data regarding day 42",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "42"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "43_demand_train",
#           "name": "43",
#           "description": "The data regarding day 43",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "43"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "44_demand_train",
#           "name": "44",
#           "description": "The data regarding day 44",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "44"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "45_demand_train",
#           "name": "45",
#           "description": "The data regarding day 45",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "45"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "46_demand_train",
#           "name": "46",
#           "description": "The data regarding day 46",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "46"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "47_demand_train",
#           "name": "47",
#           "description": "The data regarding day 47",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "47"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "48_demand_train",
#           "name": "48",
#           "description": "The data regarding day 48",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "48"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "49_demand_train",
#           "name": "49",
#           "description": "The data regarding day 49",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "49"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "50_demand_train",
#           "name": "50",
#           "description": "The data regarding day 50",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "50"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "51_demand_train",
#           "name": "51",
#           "description": "The data regarding day 51",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "51"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "52_demand_train",
#           "name": "52",
#           "description": "The data regarding day 52",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "52"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "53_demand_train",
#           "name": "53",
#           "description": "The data regarding day 53",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "53"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "54_demand_train",
#           "name": "54",
#           "description": "The data regarding day 54",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "54"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "55_demand_train",
#           "name": "55",
#           "description": "The data regarding day 55",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "55"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "56_demand_train",
#           "name": "56",
#           "description": "The data regarding day 56",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "56"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "57_demand_train",
#           "name": "57",
#           "description": "The data regarding day 57",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "57"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "58_demand_train",
#           "name": "58",
#           "description": "The data regarding day 58",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "58"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "59_demand_train",
#           "name": "59",
#           "description": "The data regarding day 59",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "59"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "60_demand_train",
#           "name": "60",
#           "description": "The data regarding day 60",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "60"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "61_demand_train",
#           "name": "61",
#           "description": "The data regarding day 61",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "61"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "62_demand_train",
#           "name": "62",
#           "description": "The data regarding day 62",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "62"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "63_demand_train",
#           "name": "63",
#           "description": "The data regarding day 63",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "63"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "64_demand_train",
#           "name": "64",
#           "description": "The data regarding day 64",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "64"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "65_demand_train",
#           "name": "65",
#           "description": "The data regarding day 65",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "65"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "66_demand_train",
#           "name": "66",
#           "description": "The data regarding day 66",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "66"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "67_demand_train",
#           "name": "67",
#           "description": "The data regarding day 67",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "67"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "68_demand_train",
#           "name": "68",
#           "description": "The data regarding day 68",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "68"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "69_demand_train",
#           "name": "69",
#           "description": "The data regarding day 69",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "69"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "70_demand_train",
#           "name": "70",
#           "description": "The data regarding day 70",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "70"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "71_demand_train",
#           "name": "71",
#           "description": "The data regarding day 71",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "71"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "72_demand_train",
#           "name": "72",
#           "description": "The data regarding day 72",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "72"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "73_demand_train",
#           "name": "73",
#           "description": "The data regarding day 73",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "73"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "74_demand_train",
#           "name": "74",
#           "description": "The data regarding day 74",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "74"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "75_demand_train",
#           "name": "75",
#           "description": "The data regarding day 75",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "75"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "76_demand_train",
#           "name": "76",
#           "description": "The data regarding day 76",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "76"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "77_demand_train",
#           "name": "77",
#           "description": "The data regarding day 77",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "77"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "78_demand_train",
#           "name": "78",
#           "description": "The data regarding day 78",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "78"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "79_demand_train",
#           "name": "79",
#           "description": "The data regarding day 79",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "79"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "80_demand_train",
#           "name": "80",
#           "description": "The data regarding day 80",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "80"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "81_demand_train",
#           "name": "81",
#           "description": "The data regarding day 81",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "81"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "82_demand_train",
#           "name": "82",
#           "description": "The data regarding day 82",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "82"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "83_demand_train",
#           "name": "83",
#           "description": "The data regarding day 83",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "83"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "84_demand_train",
#           "name": "84",
#           "description": "The data regarding day 84",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "84"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "85_demand_train",
#           "name": "85",
#           "description": "The data regarding day 85",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "85"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "86_demand_train",
#           "name": "86",
#           "description": "The data regarding day 86",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "86"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "87_demand_train",
#           "name": "87",
#           "description": "The data regarding day 87",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "87"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "88_demand_train",
#           "name": "88",
#           "description": "The data regarding day 88",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "88"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "89_demand_train",
#           "name": "89",
#           "description": "The data regarding day 89",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "89"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "90_demand_train",
#           "name": "90",
#           "description": "The data regarding day 90",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "90"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "91_demand_train",
#           "name": "91",
#           "description": "The data regarding day 91",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "91"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "92_demand_train",
#           "name": "92",
#           "description": "The data regarding day 92",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "92"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "93_demand_train",
#           "name": "93",
#           "description": "The data regarding day 93",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "93"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "94_demand_train",
#           "name": "94",
#           "description": "The data regarding day 94",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "94"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "95_demand_train",
#           "name": "95",
#           "description": "The data regarding day 95",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "95"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "96_demand_train",
#           "name": "96",
#           "description": "The data regarding day 96",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "96"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "97_demand_train",
#           "name": "97",
#           "description": "The data regarding day 97",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "97"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "98_demand_train",
#           "name": "98",
#           "description": "The data regarding day 98",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "98"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "99_demand_train",
#           "name": "99",
#           "description": "The data regarding day 99",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "99"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "100_demand_train",
#           "name": "100",
#           "description": "The data regarding day 100",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "100"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "101_demand_train",
#           "name": "101",
#           "description": "The data regarding day 101",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "101"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "102_demand_train",
#           "name": "102",
#           "description": "The data regarding day 102",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "102"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "103_demand_train",
#           "name": "103",
#           "description": "The data regarding day 103",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "103"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "104_demand_train",
#           "name": "104",
#           "description": "The data regarding day 104",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "104"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "105_demand_train",
#           "name": "105",
#           "description": "The data regarding day 105",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "105"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "106_demand_train",
#           "name": "106",
#           "description": "The data regarding day 106",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "106"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "107_demand_train",
#           "name": "107",
#           "description": "The data regarding day 107",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "107"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "108_demand_train",
#           "name": "108",
#           "description": "The data regarding day 108",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "108"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "109_demand_train",
#           "name": "109",
#           "description": "The data regarding day 109",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "109"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "110_demand_train",
#           "name": "110",
#           "description": "The data regarding day 110",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "110"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "111_demand_train",
#           "name": "111",
#           "description": "The data regarding day 111",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "111"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "112_demand_train",
#           "name": "112",
#           "description": "The data regarding day 112",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "112"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "113_demand_train",
#           "name": "113",
#           "description": "The data regarding day 113",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "113"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "114_demand_train",
#           "name": "114",
#           "description": "The data regarding day 114",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "114"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "115_demand_train",
#           "name": "115",
# ...
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "325"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "326_inflow_test",
#           "name": "326",
#           "description": "The data regarding day 326",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "326"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "327_inflow_test",
#           "name": "327",
#           "description": "The data regarding day 327",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "327"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "328_inflow_test",
#           "name": "328",
#           "description": "The data regarding day 328",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "328"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "329_inflow_test",
#           "name": "329",
#           "description": "The data regarding day 329",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "329"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "330_inflow_test",
#           "name": "330",
#           "description": "The data regarding day 330",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "330"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "331_inflow_test",
#           "name": "331",
#           "description": "The data regarding day 331",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "331"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "332_inflow_test",
#           "name": "332",
#           "description": "The data regarding day 332",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "332"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "333_inflow_test",
#           "name": "333",
#           "description": "The data regarding day 333",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "333"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "334_inflow_test",
#           "name": "334",
#           "description": "The data regarding day 334",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "334"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "335_inflow_test",
#           "name": "335",
#           "description": "The data regarding day 335",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "335"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "336_inflow_test",
#           "name": "336",
#           "description": "The data regarding day 336",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "336"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "337_inflow_test",
#           "name": "337",
#           "description": "The data regarding day 337",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "337"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "338_inflow_test",
#           "name": "338",
#           "description": "The data regarding day 338",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "338"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "339_inflow_test",
#           "name": "339",
#           "description": "The data regarding day 339",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "339"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "340_inflow_test",
#           "name": "340",
#           "description": "The data regarding day 340",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "340"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "341_inflow_test",
#           "name": "341",
#           "description": "The data regarding day 341",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "341"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "342_inflow_test",
#           "name": "342",
#           "description": "The data regarding day 342",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "342"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "343_inflow_test",
#           "name": "343",
#           "description": "The data regarding day 343",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "343"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "344_inflow_test",
#           "name": "344",
#           "description": "The data regarding day 344",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "344"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "345_inflow_test",
#           "name": "345",
#           "description": "The data regarding day 345",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "345"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "346_inflow_test",
#           "name": "346",
#           "description": "The data regarding day 346",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "346"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "347_inflow_test",
#           "name": "347",
#           "description": "The data regarding day 347",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "347"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "348_inflow_test",
#           "name": "348",
#           "description": "The data regarding day 348",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "348"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "349_inflow_test",
#           "name": "349",
#           "description": "The data regarding day 349",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "349"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "350_inflow_test",
#           "name": "350",
#           "description": "The data regarding day 350",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "350"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "351_inflow_test",
#           "name": "351",
#           "description": "The data regarding day 351",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "351"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "352_inflow_test",
#           "name": "352",
#           "description": "The data regarding day 352",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "352"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "353_inflow_test",
#           "name": "353",
#           "description": "The data regarding day 353",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "353"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "354_inflow_test",
#           "name": "354",
#           "description": "The data regarding day 354",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "354"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "355_inflow_test",
#           "name": "355",
#           "description": "The data regarding day 355",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "355"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "356_inflow_test",
#           "name": "356",
#           "description": "The data regarding day 356",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "356"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "357_inflow_test",
#           "name": "357",
#           "description": "The data regarding day 357",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "357"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "358_inflow_test",
#           "name": "358",
#           "description": "The data regarding day 358",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "358"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "359_inflow_test",
#           "name": "359",
#           "description": "The data regarding day 359",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "359"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "360_inflow_test",
#           "name": "360",
#           "description": "The data regarding day 360",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "360"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "361_inflow_test",
#           "name": "361",
#           "description": "The data regarding day 361",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "361"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "362_inflow_test",
#           "name": "362",
#           "description": "The data regarding day 362",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "362"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "363_inflow_test",
#           "name": "363",
#           "description": "The data regarding day 363",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "363"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "364_inflow_test",
#           "name": "364",
#           "description": "The data regarding day 364",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "364"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "365_inflow_test",
#           "name": "365",
#           "description": "The data regarding day 365",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "inflow_test"
#             },
#             "extract": {
#               "column": "365"
#             }
#           }
#         }
#       ]
#     },
#     {
#       "@type": "cr:RecordSet",
#       "@id": "mef_table",
#       "name": "mef_table",
#       "field": [
#         {
#           "@type": "cr:Field",
#           "@id": "MEF",
#           "name": "MEF",
#           "description": "The year that the data was collected in",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "mef_file_object"
#             },
#             "extract": {
#               "column": "MEF"
#             }
#           }
#         }
#       ]
#     }
#   ]
# }

# %%
dataset = mlc.Dataset(jsonld="metadata_dam.json")
# Out:
# WARNING:absl:Found the following 3 warning(s) during the validation:
#   -  [Metadata(dam_data)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
#   -  [Metadata(dam_data)] Property "https://schema.org/datePublished" is recommended, but does not exist.
#   -  [Metadata(dam_data)] Property "https://schema.org/version" is recommended, but does not exist.

# %%
records = dataset.records(record_set="demand_train_table")

for i, record in enumerate(records):
  print(record)
  if i == 10:
      break
# Out:
# {'year_demand_train': 1985, '0_demand_train': 84.3, '1_demand_train': 113.6, '2_demand_train': 113.9, '3_demand_train': 96.6, '4_demand_train': 83.0, '5_demand_train': 83.1, '6_demand_train': 98.5, '7_demand_train': 98.7, '8_demand_train': 98.7, '9_demand_train': 98.7, '10_demand_train': 88.9, '11_demand_train': 82.9, '12_demand_train': 83.9, '13_demand_train': 99.1, '14_demand_train': 111.5, '15_demand_train': 114.9, '16_demand_train': 128.5, '17_demand_train': 133.0, '18_demand_train': 131.1, '19_demand_train': 131.9, '20_demand_train': 133.2, '21_demand_train': 119.3, '22_demand_train': 115.0, '23_demand_train': 117.6, '24_demand_train': 114.3, '25_demand_train': 113.1, '26_demand_train': 112.5, '27_demand_train': 113.9, '28_demand_train': 114.4, '29_demand_train': 113.7, '30_demand_train': 112.8, '31_demand_train': 112.8, '32_demand_train': 112.8, '33_demand_train': 113.4, '34_demand_train': 113.6, '35_demand_train': 115.0, '36_demand_train': 115.0, '37_demand_train': 115.0, '38_demand_train': 115.0, '39_demand_train': 114.6, '40_demand_train': 113.7, '41_demand_train': 112.8, '42_demand_train': 112.8, '43_demand_train': 112.8, '44_demand_train': 112.8, '45_demand_train': 96.2, '46_demand_train': 84.8, '47_demand_train': 87.3, '48_demand_train': 116.1, '49_demand_train': 115.7, '50_demand_train': 115.0, '51_demand_train': 115.0, '52_demand_train': 99.5, '53_demand_train': 85.2, '54_demand_train': 86.0, '55_demand_train': 114.8, '56_demand_train': 107.3, '57_demand_train': 100.0, '58_demand_train': 100.0, '59_demand_train': 84.2, '60_demand_train': 72.6, '61_demand_train': 74.1, '62_demand_train': 100.5, '63_demand_train': 102.6, '64_demand_train': 102.7, '65_demand_train': 101.0, '66_demand_train': 102.3, '67_demand_train': 101.0, '68_demand_train': 100.7, '69_demand_train': 100.7, '70_demand_train': 101.7, '71_demand_train': 116.3, '72_demand_train': 116.5, '73_demand_train': 116.5, '74_demand_train': 117.2, '75_demand_train': 116.9, '76_demand_train': 116.1, '77_demand_train': 115.7, '78_demand_train': 115.7, '79_demand_train': 116.8, '80_demand_train': 115.9, '81_demand_train': 115.0, '82_demand_train': 115.0, '83_demand_train': 128.0, '84_demand_train': 131.0, '85_demand_train': 132.6, '86_demand_train': 132.2, '87_demand_train': 130.3, '88_demand_train': 130.0, '89_demand_train': 130.5, '90_demand_train': 130.0, '91_demand_train': 130.0, '92_demand_train': 130.8, '93_demand_train': 130.8, '94_demand_train': 131.9, '95_demand_train': 134.5, '96_demand_train': 133.4, '97_demand_train': 133.8, '98_demand_train': 153.9, '99_demand_train': 163.0, '100_demand_train': 189.9, '101_demand_train': 216.5, '102_demand_train': 217.0, '103_demand_train': 214.2, '104_demand_train': 193.3, '105_demand_train': 189.2, '106_demand_train': 189.5, '107_demand_train': 188.8, '108_demand_train': 190.0, '109_demand_train': 188.9, '110_demand_train': 188.9, '111_demand_train': 190.5, '112_demand_train': 190.5, '113_demand_train': 189.4, '114_demand_train': 187.9, '115_demand_train': 189.8, '116_demand_train': 189.8, '117_demand_train': 190.7, '118_demand_train': 190.3, '119_demand_train': 188.6, '120_demand_train': 188.8, '121_demand_train': 171.2, '122_demand_train': 159.9, '123_demand_train': 151.0, '124_demand_train': 149.6, '125_demand_train': 149.6, '126_demand_train': 153.7, '127_demand_train': 182.2, '128_demand_train': 189.1, '129_demand_train': 189.1, '130_demand_train': 188.1, '131_demand_train': 189.8, '132_demand_train': 214.6, '133_demand_train': 269.1, '134_demand_train': 333.6, '135_demand_train': 364.5, '136_demand_train': 351.7, '137_demand_train': 342.4, '138_demand_train': 339.2, '139_demand_train': 345.9, '140_demand_train': 352.9, '141_demand_train': 384.6, '142_demand_train': 394.1, '143_demand_train': 376.3, '144_demand_train': 324.4, '145_demand_train': 283.7, '146_demand_train': 281.4, '147_demand_train': 286.6, '148_demand_train': 309.7, '149_demand_train': 347.1, '150_demand_train': 346.2, '151_demand_train': 347.3, ...
# {'year_demand_train': 1959, '0_demand_train': 99.0, '1_demand_train': 99.0, '2_demand_train': 99.0, '3_demand_train': 100.0, '4_demand_train': 99.0, '5_demand_train': 99.0, '6_demand_train': 122.0, '7_demand_train': 122.0, '8_demand_train': 122.0, '9_demand_train': 121.0, '10_demand_train': 122.0, '11_demand_train': 123.0, '12_demand_train': 122.0, '13_demand_train': 122.0, '14_demand_train': 120.0, '15_demand_train': 121.0, '16_demand_train': 121.0, '17_demand_train': 118.0, '18_demand_train': 119.0, '19_demand_train': 119.0, '20_demand_train': 119.0, '21_demand_train': 119.0, '22_demand_train': 119.0, '23_demand_train': 119.0, '24_demand_train': 119.0, '25_demand_train': 119.0, '26_demand_train': 119.0, '27_demand_train': 121.0, '28_demand_train': 120.0, '29_demand_train': 119.0, '30_demand_train': 119.0, '31_demand_train': 119.0, '32_demand_train': 119.0, '33_demand_train': 119.0, '34_demand_train': 119.0, '35_demand_train': 119.0, '36_demand_train': 119.0, '37_demand_train': 119.0, '38_demand_train': 116.0, '39_demand_train': 119.0, '40_demand_train': 119.0, '41_demand_train': 119.0, '42_demand_train': 120.0, '43_demand_train': 119.0, '44_demand_train': 119.0, '45_demand_train': 119.0, '46_demand_train': 119.0, '47_demand_train': 115.0, '48_demand_train': 111.0, '49_demand_train': 110.0, '50_demand_train': 110.0, '51_demand_train': 110.0, '52_demand_train': 110.0, '53_demand_train': 110.0, '54_demand_train': 104.0, '55_demand_train': 99.0, '56_demand_train': 99.0, '57_demand_train': 101.0, '58_demand_train': 102.0, '59_demand_train': 100.0, '60_demand_train': 99.0, '61_demand_train': 100.0, '62_demand_train': 103.0, '63_demand_train': 103.0, '64_demand_train': 103.0, '65_demand_train': 110.0, '66_demand_train': 101.0, '67_demand_train': 115.0, '68_demand_train': 122.0, '69_demand_train': 121.0, '70_demand_train': 121.0, '71_demand_train': 120.0, '72_demand_train': 119.0, '73_demand_train': 119.0, '74_demand_train': 119.0, '75_demand_train': 119.0, '76_demand_train': 116.0, '77_demand_train': 115.0, '78_demand_train': 115.0, '79_demand_train': 115.0, '80_demand_train': 113.0, '81_demand_train': 116.0, '82_demand_train': 115.0, '83_demand_train': 103.0, '84_demand_train': 78.0, '85_demand_train': 72.0, '86_demand_train': 62.0, '87_demand_train': 61.0, '88_demand_train': 86.0, '89_demand_train': 107.0, '90_demand_train': 115.0, '91_demand_train': 115.0, '92_demand_train': 116.0, '93_demand_train': 115.0, '94_demand_train': 115.0, '95_demand_train': 113.0, '96_demand_train': 116.0, '97_demand_train': 117.0, '98_demand_train': 116.0, '99_demand_train': 116.0, '100_demand_train': 116.0, '101_demand_train': 116.0, '102_demand_train': 116.0, '103_demand_train': 116.0, '104_demand_train': 116.0, '105_demand_train': 119.0, '106_demand_train': 118.0, '107_demand_train': 118.0, '108_demand_train': 118.0, '109_demand_train': 116.0, '110_demand_train': 124.0, '111_demand_train': 130.0, '112_demand_train': 130.0, '113_demand_train': 130.0, '114_demand_train': 129.0, '115_demand_train': 128.0, '116_demand_train': 130.0, '117_demand_train': 130.0, '118_demand_train': 130.0, '119_demand_train': 132.0, '120_demand_train': 122.0, '121_demand_train': 123.0, '122_demand_train': 125.0, '123_demand_train': 125.0, '124_demand_train': 127.0, '125_demand_train': 130.0, '126_demand_train': 132.0, '127_demand_train': 132.0, '128_demand_train': 132.0, '129_demand_train': 132.0, '130_demand_train': 133.0, '131_demand_train': 132.0, '132_demand_train': 131.0, '133_demand_train': 132.0, '134_demand_train': 132.0, '135_demand_train': 132.0, '136_demand_train': 132.0, '137_demand_train': 132.0, '138_demand_train': 140.0, '139_demand_train': 146.0, '140_demand_train': 150.0, '141_demand_train': 152.0, '142_demand_train': 151.0, '143_demand_train': 152.0, '144_demand_train': 152.0, '145_demand_train': 152.0, '146_demand_train': 152.0, '147_demand_train': 152.0, '148_demand_train': 203.0, '149_demand_train': 208.0, '150_demand_train': 207.0, '151_demand_train' ...
# {'year_demand_train': 1997, '0_demand_train': 140.3, '1_demand_train': 139.7, '2_demand_train': 139.8, '3_demand_train': 140.3, '4_demand_train': 139.2, '5_demand_train': 138.5, '6_demand_train': 138.5, '7_demand_train': 138.5, '8_demand_train': 138.5, '9_demand_train': 125.6, '10_demand_train': 120.9, '11_demand_train': 120.4, '12_demand_train': 138.6, '13_demand_train': 139.4, '14_demand_train': 138.8, '15_demand_train': 138.0, '16_demand_train': 112.2, '17_demand_train': 112.2, '18_demand_train': 112.5, '19_demand_train': 130.1, '20_demand_train': 130.5, '21_demand_train': 130.5, '22_demand_train': 130.5, '23_demand_train': 107.2, '24_demand_train': 100.7, '25_demand_train': 100.8, '26_demand_train': 119.9, '27_demand_train': 121.1, '28_demand_train': 121.1, '29_demand_train': 121.1, '30_demand_train': 104.5, '31_demand_train': 99.2, '32_demand_train': 99.1, '33_demand_train': 121.0, '34_demand_train': 122.0, '35_demand_train': 122.0, '36_demand_train': 121.5, '37_demand_train': 105.8, '38_demand_train': 100.7, '39_demand_train': 100.3, '40_demand_train': 99.6, '41_demand_train': 99.2, '42_demand_train': 99.2, '43_demand_train': 99.3, '44_demand_train': 99.2, '45_demand_train': 99.6, '46_demand_train': 98.1, '47_demand_train': 100.6, '48_demand_train': 100.7, '49_demand_train': 100.7, '50_demand_train': 100.0, '51_demand_train': 89.4, '52_demand_train': 86.2, '53_demand_train': 85.7, '54_demand_train': 85.2, '55_demand_train': 85.2, '56_demand_train': 85.4, '57_demand_train': 86.0, '58_demand_train': 80.4, '59_demand_train': 79.4, '60_demand_train': 79.4, '61_demand_train': 77.8, '62_demand_train': 77.5, '63_demand_train': 77.5, '64_demand_train': 77.5, '65_demand_train': 78.1, '66_demand_train': 78.1, '67_demand_train': 78.1, '68_demand_train': 77.7, '69_demand_train': 77.5, '70_demand_train': 78.1, '71_demand_train': 78.1, '72_demand_train': 78.1, '73_demand_train': 78.6, '74_demand_train': 78.1, '75_demand_train': 85.3, '76_demand_train': 86.6, '77_demand_train': 87.1, '78_demand_train': 85.6, '79_demand_train': 85.8, '80_demand_train': 85.2, '81_demand_train': 85.2, '82_demand_train': 84.6, '83_demand_train': 84.6, '84_demand_train': 84.6, '85_demand_train': 85.2, '86_demand_train': 86.1, '87_demand_train': 85.5, '88_demand_train': 85.7, '89_demand_train': 84.5, '90_demand_train': 84.8, '91_demand_train': 86.4, '92_demand_train': 86.6, '93_demand_train': 87.1, '94_demand_train': 86.6, '95_demand_train': 86.5, '96_demand_train': 85.5, '97_demand_train': 85.2, '98_demand_train': 85.2, '99_demand_train': 85.2, '100_demand_train': 86.1, '101_demand_train': 87.5, '102_demand_train': 86.6, '103_demand_train': 79.4, '104_demand_train': 74.6, '105_demand_train': 75.4, '106_demand_train': 75.0, '107_demand_train': 61.9, '108_demand_train': 60.7, '109_demand_train': 60.0, '110_demand_train': 60.0, '111_demand_train': 61.2, '112_demand_train': 61.1, '113_demand_train': 61.1, '114_demand_train': 61.3, '115_demand_train': 61.4, '116_demand_train': 64.1, '117_demand_train': 63.8, '118_demand_train': 64.1, '119_demand_train': 60.7, '120_demand_train': 60.5, '121_demand_train': 60.5, '122_demand_train': 60.6, '123_demand_train': 60.6, '124_demand_train': 60.9, '125_demand_train': 62.8, '126_demand_train': 82.6, '127_demand_train': 86.9, '128_demand_train': 88.0, '129_demand_train': 88.0, '130_demand_train': 88.6, '131_demand_train': 88.7, '132_demand_train': 89.5, '133_demand_train': 104.1, '134_demand_train': 108.2, '135_demand_train': 109.4, '136_demand_train': 110.5, '137_demand_train': 111.0, '138_demand_train': 121.8, '139_demand_train': 126.7, '140_demand_train': 128.6, '141_demand_train': 138.5, '142_demand_train': 142.7, '143_demand_train': 147.6, '144_demand_train': 148.1, '145_demand_train': 153.7, '146_demand_train': 155.4, '147_demand_train': 155.4, '148_demand_train': 156.3, '149_demand_train': 160.7, '150_demand_train': 162.2, '151_demand_train': 162.3, '152_demand_train': 161.6, '153_demand_train': 161.3, '154_demand_tra ...
# {'year_demand_train': 2008, '0_demand_train': 45.28, '1_demand_train': 45.04, '2_demand_train': 45.22, '3_demand_train': 45.34, '4_demand_train': 45.84, '5_demand_train': 45.89, '6_demand_train': 45.8, '7_demand_train': 50.58, '8_demand_train': 50.87, '9_demand_train': 52.0, '10_demand_train': 52.07, '11_demand_train': 53.59, '12_demand_train': 52.86, '13_demand_train': 78.27, '14_demand_train': 83.06, '15_demand_train': 83.97, '16_demand_train': 81.28, '17_demand_train': 81.38, '18_demand_train': 81.34, '19_demand_train': 81.08, '20_demand_train': 81.59, '21_demand_train': 81.45, '22_demand_train': 80.88, '23_demand_train': 80.94, '24_demand_train': 80.96, '25_demand_train': 81.25, '26_demand_train': 81.11, '27_demand_train': 80.44, '28_demand_train': 80.18, '29_demand_train': 80.29, '30_demand_train': 80.3, '31_demand_train': 80.19, '32_demand_train': 80.03, '33_demand_train': 79.77, '34_demand_train': 80.75, '35_demand_train': 80.57, '36_demand_train': 80.36, '37_demand_train': 80.09, '38_demand_train': 80.13, '39_demand_train': 80.01, '40_demand_train': 79.75, '41_demand_train': 79.87, '42_demand_train': 79.79, '43_demand_train': 79.89, '44_demand_train': 79.69, '45_demand_train': 79.58, '46_demand_train': 79.21, '47_demand_train': 78.87, '48_demand_train': 79.69, '49_demand_train': 79.92, '50_demand_train': 79.64, '51_demand_train': 79.51, '52_demand_train': 79.35, '53_demand_train': 78.82, '54_demand_train': 78.33, '55_demand_train': 78.06, '56_demand_train': 79.39, '57_demand_train': 79.39, '58_demand_train': 79.04, '59_demand_train': 71.06, '60_demand_train': 70.89, '61_demand_train': 70.53, '62_demand_train': 70.21, '63_demand_train': 70.26, '64_demand_train': 70.47, '65_demand_train': 70.01, '66_demand_train': 65.61, '67_demand_train': 65.39, '68_demand_train': 65.37, '69_demand_train': 66.59, '70_demand_train': 67.12, '71_demand_train': 67.14, '72_demand_train': 68.21, '73_demand_train': 68.5, '74_demand_train': 68.6, '75_demand_train': 68.76, '76_demand_train': 65.67, '77_demand_train': 65.55, '78_demand_train': 65.55, '79_demand_train': 65.7, '80_demand_train': 65.82, '81_demand_train': 65.85, '82_demand_train': 65.65, '83_demand_train': 65.29, '84_demand_train': 64.81, '85_demand_train': 64.86, '86_demand_train': 64.96, '87_demand_train': 55.19, '88_demand_train': 55.57, '89_demand_train': 55.44, '90_demand_train': 55.35, '91_demand_train': 55.62, '92_demand_train': 55.54, '93_demand_train': 54.0, '94_demand_train': 53.78, '95_demand_train': 53.77, '96_demand_train': 53.88, '97_demand_train': 53.78, '98_demand_train': 53.77, '99_demand_train': 54.1, '100_demand_train': 53.7, '101_demand_train': 55.88, '102_demand_train': 54.2, '103_demand_train': 56.36, '104_demand_train': 87.99, '105_demand_train': 102.6, '106_demand_train': 113.79, '107_demand_train': 115.83, '108_demand_train': 129.44, '109_demand_train': 130.83, '110_demand_train': 130.94, '111_demand_train': 133.27, '112_demand_train': 133.55, '113_demand_train': 132.99, '114_demand_train': 133.1, '115_demand_train': 133.13, '116_demand_train': 132.72, '117_demand_train': 132.45, '118_demand_train': 133.7, '119_demand_train': 133.77, '120_demand_train': 134.46, '121_demand_train': 133.92, '122_demand_train': 133.98, '123_demand_train': 133.8, '124_demand_train': 133.78, '125_demand_train': 133.68, '126_demand_train': 139.71, '127_demand_train': 140.98, '128_demand_train': 149.31, '129_demand_train': 151.81, '130_demand_train': 152.24, '131_demand_train': 152.49, '132_demand_train': 159.74, '133_demand_train': 168.99, '134_demand_train': 170.41, '135_demand_train': 221.99, '136_demand_train': 347.71, '137_demand_train': 407.5, '138_demand_train': 455.7, '139_demand_train': 482.1, '140_demand_train': 440.8, '141_demand_train': 467.2, '142_demand_train': 453.4, '143_demand_train': 451.1, '144_demand_train': 436.2, '145_demand_train': 427.0, '146_demand_train': 413.3, '147_demand_train': 329.5, '148_demand_train': 327.2, '149_demand_train': 331.8, '150_demand_tr ...
# {'year_demand_train': 2006, '0_demand_train': 44.98, '1_demand_train': 44.53, '2_demand_train': 40.43, '3_demand_train': 37.51, '4_demand_train': 36.8, '5_demand_train': 36.67, '6_demand_train': 36.56, '7_demand_train': 36.4, '8_demand_train': 36.48, '9_demand_train': 36.6, '10_demand_train': 40.58, '11_demand_train': 40.62, '12_demand_train': 40.72, '13_demand_train': 40.77, '14_demand_train': 40.64, '15_demand_train': 44.79, '16_demand_train': 45.95, '17_demand_train': 46.03, '18_demand_train': 46.18, '19_demand_train': 46.08, '20_demand_train': 45.63, '21_demand_train': 45.98, '22_demand_train': 45.95, '23_demand_train': 46.44, '24_demand_train': 46.72, '25_demand_train': 46.8, '26_demand_train': 47.7, '27_demand_train': 45.8, '28_demand_train': 45.5, '29_demand_train': 45.46, '30_demand_train': 51.18, '31_demand_train': 52.27, '32_demand_train': 52.45, '33_demand_train': 52.8, '34_demand_train': 52.55, '35_demand_train': 52.22, '36_demand_train': 56.25, '37_demand_train': 56.98, '38_demand_train': 57.05, '39_demand_train': 56.01, '40_demand_train': 55.0, '41_demand_train': 54.92, '42_demand_train': 54.74, '43_demand_train': 64.48, '44_demand_train': 65.96, '45_demand_train': 65.94, '46_demand_train': 66.03, '47_demand_train': 65.96, '48_demand_train': 66.86, '49_demand_train': 67.62, '50_demand_train': 74.43, '51_demand_train': 76.04, '52_demand_train': 75.85, '53_demand_train': 75.97, '54_demand_train': 76.62, '55_demand_train': 77.48, '56_demand_train': 77.08, '57_demand_train': 76.69, '58_demand_train': 76.49, '59_demand_train': 76.48, '60_demand_train': 76.4, '61_demand_train': 76.26, '62_demand_train': 76.5, '63_demand_train': 77.51, '64_demand_train': 76.29, '65_demand_train': 76.56, '66_demand_train': 76.37, '67_demand_train': 76.26, '68_demand_train': 76.27, '69_demand_train': 76.09, '70_demand_train': 75.99, '71_demand_train': 74.5, '72_demand_train': 74.14, '73_demand_train': 74.09, '74_demand_train': 73.83, '75_demand_train': 66.08, '76_demand_train': 65.09, '77_demand_train': 64.81, '78_demand_train': 64.62, '79_demand_train': 64.73, '80_demand_train': 64.42, '81_demand_train': 65.25, '82_demand_train': 60.2, '83_demand_train': 59.58, '84_demand_train': 59.4, '85_demand_train': 59.21, '86_demand_train': 60.94, '87_demand_train': 60.18, '88_demand_train': 60.65, '89_demand_train': 60.89, '90_demand_train': 60.97, '91_demand_train': 61.11, '92_demand_train': 60.97, '93_demand_train': 61.09, '94_demand_train': 70.59, '95_demand_train': 72.06, '96_demand_train': 71.83, '97_demand_train': 71.97, '98_demand_train': 71.84, '99_demand_train': 73.35, '100_demand_train': 80.66, '101_demand_train': 81.37, '102_demand_train': 81.51, '103_demand_train': 81.56, '104_demand_train': 81.81, '105_demand_train': 81.86, '106_demand_train': 82.04, '107_demand_train': 82.44, '108_demand_train': 90.66, '109_demand_train': 91.43, '110_demand_train': 91.43, '111_demand_train': 91.5, '112_demand_train': 91.64, '113_demand_train': 91.71, '114_demand_train': 91.7, '115_demand_train': 91.9, '116_demand_train': 91.98, '117_demand_train': 91.88, '118_demand_train': 93.01, '119_demand_train': 93.02, '120_demand_train': 93.01, '121_demand_train': 92.99, '122_demand_train': 92.84, '123_demand_train': 100.02, '124_demand_train': 101.97, '125_demand_train': 102.32, '126_demand_train': 102.1, '127_demand_train': 101.26, '128_demand_train': 101.15, '129_demand_train': 101.05, '130_demand_train': 101.07, '131_demand_train': 101.63, '132_demand_train': 102.72, '133_demand_train': 103.53, '134_demand_train': 109.29, '135_demand_train': 110.27, '136_demand_train': 111.17, '137_demand_train': 119.7, '138_demand_train': 122.41, '139_demand_train': 121.66, '140_demand_train': 122.57, '141_demand_train': 149.73, '142_demand_train': 151.01, '143_demand_train': 151.66, '144_demand_train': 159.85, '145_demand_train': 167.38, '146_demand_train': 167.47, '147_demand_train': 168.93, '148_demand_train': 169.3, '149_demand_train': 177.75, '150_demand_train': 180.3 ...
# {'year_demand_train': 2004, '0_demand_train': 77.46, '1_demand_train': 77.88, '2_demand_train': 77.93, '3_demand_train': 77.55, '4_demand_train': 77.32, '5_demand_train': 77.33, '6_demand_train': 85.91, '7_demand_train': 87.04, '8_demand_train': 87.25, '9_demand_train': 87.4, '10_demand_train': 86.77, '11_demand_train': 86.61, '12_demand_train': 86.58, '13_demand_train': 105.29, '14_demand_train': 107.3, '15_demand_train': 106.81, '16_demand_train': 105.95, '17_demand_train': 105.25, '18_demand_train': 104.11, '19_demand_train': 103.99, '20_demand_train': 104.17, '21_demand_train': 104.61, '22_demand_train': 88.87, '23_demand_train': 87.38, '24_demand_train': 86.71, '25_demand_train': 86.11, '26_demand_train': 86.37, '27_demand_train': 86.58, '28_demand_train': 86.68, '29_demand_train': 86.29, '30_demand_train': 85.76, '31_demand_train': 84.9, '32_demand_train': 84.57, '33_demand_train': 84.44, '34_demand_train': 84.62, '35_demand_train': 84.46, '36_demand_train': 84.45, '37_demand_train': 84.49, '38_demand_train': 83.85, '39_demand_train': 84.53, '40_demand_train': 84.93, '41_demand_train': 84.97, '42_demand_train': 84.56, '43_demand_train': 73.31, '44_demand_train': 70.84, '45_demand_train': 70.22, '46_demand_train': 69.84, '47_demand_train': 70.04, '48_demand_train': 70.46, '49_demand_train': 71.59, '50_demand_train': 72.01, '51_demand_train': 73.75, '52_demand_train': 74.07, '53_demand_train': 90.32, '54_demand_train': 92.01, '55_demand_train': 91.69, '56_demand_train': 91.46, '57_demand_train': 91.45, '58_demand_train': 91.3, '59_demand_train': 90.5, '60_demand_train': 89.98, '61_demand_train': 89.74, '62_demand_train': 89.92, '63_demand_train': 89.82, '64_demand_train': 89.86, '65_demand_train': 89.73, '66_demand_train': 89.2, '67_demand_train': 88.59, '68_demand_train': 88.58, '69_demand_train': 88.8, '70_demand_train': 89.92, '71_demand_train': 90.09, '72_demand_train': 90.09, '73_demand_train': 89.29, '74_demand_train': 89.01, '75_demand_train': 89.26, '76_demand_train': 107.71, '77_demand_train': 110.02, '78_demand_train': 110.07, '79_demand_train': 110.01, '80_demand_train': 109.33, '81_demand_train': 109.36, '82_demand_train': 109.28, '83_demand_train': 109.31, '84_demand_train': 109.05, '85_demand_train': 109.03, '86_demand_train': 108.5, '87_demand_train': 108.89, '88_demand_train': 108.34, '89_demand_train': 108.66, '90_demand_train': 108.36, '91_demand_train': 108.69, '92_demand_train': 91.08, '93_demand_train': 90.28, '94_demand_train': 89.71, '95_demand_train': 89.26, '96_demand_train': 76.33, '97_demand_train': 75.8, '98_demand_train': 76.14, '99_demand_train': 76.64, '100_demand_train': 76.93, '101_demand_train': 76.83, '102_demand_train': 76.25, '103_demand_train': 75.94, '104_demand_train': 75.9, '105_demand_train': 75.89, '106_demand_train': 75.99, '107_demand_train': 76.05, '108_demand_train': 76.04, '109_demand_train': 78.78, '110_demand_train': 79.12, '111_demand_train': 90.95, '112_demand_train': 91.1, '113_demand_train': 92.44, '114_demand_train': 93.18, '115_demand_train': 93.15, '116_demand_train': 93.21, '117_demand_train': 93.45, '118_demand_train': 109.18, '119_demand_train': 111.21, '120_demand_train': 137.79, '121_demand_train': 141.41, '122_demand_train': 141.45, '123_demand_train': 142.84, '124_demand_train': 153.0, '125_demand_train': 163.79, '126_demand_train': 206.42, '127_demand_train': 211.99, '128_demand_train': 211.69, '129_demand_train': 210.51, '130_demand_train': 208.28, '131_demand_train': 205.83, '132_demand_train': 203.69, '133_demand_train': 183.88, '134_demand_train': 181.1, '135_demand_train': 179.46, '136_demand_train': 178.6, '137_demand_train': 162.44, '138_demand_train': 160.88, '139_demand_train': 161.89, '140_demand_train': 163.04, '141_demand_train': 164.91, '142_demand_train': 167.0, '143_demand_train': 167.71, '144_demand_train': 167.48, '145_demand_train': 170.92, '146_demand_train': 172.22, '147_demand_train': 172.49, '148_demand_train': 172.45, '149_demand_train' ...
# {'year_demand_train': 1962, '0_demand_train': 88.0, '1_demand_train': 99.0, '2_demand_train': 101.0, '3_demand_train': 102.0, '4_demand_train': 90.0, '5_demand_train': 85.0, '6_demand_train': 87.0, '7_demand_train': 100.0, '8_demand_train': 101.0, '9_demand_train': 120.0, '10_demand_train': 119.0, '11_demand_train': 115.0, '12_demand_train': 98.0, '13_demand_train': 89.0, '14_demand_train': 116.0, '15_demand_train': 116.0, '16_demand_train': 115.0, '17_demand_train': 114.0, '18_demand_train': 113.0, '19_demand_train': 95.0, '20_demand_train': 88.0, '21_demand_train': 115.0, '22_demand_train': 115.0, '23_demand_train': 114.0, '24_demand_train': 114.0, '25_demand_train': 114.0, '26_demand_train': 96.0, '27_demand_train': 88.0, '28_demand_train': 115.0, '29_demand_train': 115.0, '30_demand_train': 114.0, '31_demand_train': 116.0, '32_demand_train': 117.0, '33_demand_train': 91.0, '34_demand_train': 87.0, '35_demand_train': 102.0, '36_demand_train': 100.0, '37_demand_train': 101.0, '38_demand_train': 100.0, '39_demand_train': 102.0, '40_demand_train': 91.0, '41_demand_train': 87.0, '42_demand_train': 101.0, '43_demand_train': 101.0, '44_demand_train': 101.0, '45_demand_train': 101.0, '46_demand_train': 102.0, '47_demand_train': 91.0, '48_demand_train': 87.0, '49_demand_train': 99.0, '50_demand_train': 100.0, '51_demand_train': 100.0, '52_demand_train': 99.0, '53_demand_train': 100.0, '54_demand_train': 91.0, '55_demand_train': 87.0, '56_demand_train': 101.0, '57_demand_train': 100.0, '58_demand_train': 101.0, '59_demand_train': 100.0, '60_demand_train': 100.0, '61_demand_train': 90.0, '62_demand_train': 89.0, '63_demand_train': 101.0, '64_demand_train': 100.0, '65_demand_train': 99.0, '66_demand_train': 99.0, '67_demand_train': 99.0, '68_demand_train': 79.0, '69_demand_train': 65.0, '70_demand_train': 100.0, '71_demand_train': 101.0, '72_demand_train': 100.0, '73_demand_train': 100.0, '74_demand_train': 100.0, '75_demand_train': 76.0, '76_demand_train': 59.0, '77_demand_train': 65.0, '78_demand_train': 101.0, '79_demand_train': 102.0, '80_demand_train': 101.0, '81_demand_train': 99.0, '82_demand_train': 76.0, '83_demand_train': 66.0, '84_demand_train': 100.0, '85_demand_train': 96.0, '86_demand_train': 91.0, '87_demand_train': 90.0, '88_demand_train': 90.0, '89_demand_train': 72.0, '90_demand_train': 62.0, '91_demand_train': 91.0, '92_demand_train': 85.0, '93_demand_train': 81.0, '94_demand_train': 79.0, '95_demand_train': 81.0, '96_demand_train': 69.0, '97_demand_train': 62.0, '98_demand_train': 81.0, '99_demand_train': 81.0, '100_demand_train': 85.0, '101_demand_train': 91.0, '102_demand_train': 91.0, '103_demand_train': 90.0, '104_demand_train': 91.0, '105_demand_train': 89.0, '106_demand_train': 91.0, '107_demand_train': 97.0, '108_demand_train': 101.0, '109_demand_train': 120.0, '110_demand_train': 125.0, '111_demand_train': 125.0, '112_demand_train': 126.0, '113_demand_train': 128.0, '114_demand_train': 128.0, '115_demand_train': 125.0, '116_demand_train': 126.0, '117_demand_train': 128.0, '118_demand_train': 128.0, '119_demand_train': 125.0, '120_demand_train': 125.0, '121_demand_train': 124.0, '122_demand_train': 128.0, '123_demand_train': 133.0, '124_demand_train': 134.0, '125_demand_train': 134.0, '126_demand_train': 133.0, '127_demand_train': 145.0, '128_demand_train': 151.0, '129_demand_train': 150.0, '130_demand_train': 147.0, '131_demand_train': 147.0, '132_demand_train': 148.0, '133_demand_train': 145.0, '134_demand_train': 146.0, '135_demand_train': 144.0, '136_demand_train': 147.0, '137_demand_train': 145.0, '138_demand_train': 142.0, '139_demand_train': 139.0, '140_demand_train': 138.0, '141_demand_train': 141.0, '142_demand_train': 141.0, '143_demand_train': 143.0, '144_demand_train': 138.0, '145_demand_train': 142.0, '146_demand_train': 144.0, '147_demand_train': 141.0, '148_demand_train': 141.0, '149_demand_train': 141.0, '150_demand_train': 142.0, '151_demand_train': 148.0, '152_demand_train': 244.0, '153_dem ...
# {'year_demand_train': 1983, '0_demand_train': 136.0, '1_demand_train': 135.2, '2_demand_train': 134.7, '3_demand_train': 133.6, '4_demand_train': 133.6, '5_demand_train': 133.6, '6_demand_train': 133.6, '7_demand_train': 132.9, '8_demand_train': 133.6, '9_demand_train': 136.0, '10_demand_train': 135.2, '11_demand_train': 134.7, '12_demand_train': 134.4, '13_demand_train': 117.2, '14_demand_train': 105.1, '15_demand_train': 106.6, '16_demand_train': 134.7, '17_demand_train': 135.2, '18_demand_train': 135.2, '19_demand_train': 132.9, '20_demand_train': 117.4, '21_demand_train': 105.8, '22_demand_train': 106.5, '23_demand_train': 135.4, '24_demand_train': 134.4, '25_demand_train': 133.6, '26_demand_train': 133.6, '27_demand_train': 119.6, '28_demand_train': 105.3, '29_demand_train': 105.4, '30_demand_train': 134.7, '31_demand_train': 134.7, '32_demand_train': 134.7, '33_demand_train': 133.5, '34_demand_train': 116.3, '35_demand_train': 103.7, '36_demand_train': 103.1, '37_demand_train': 114.8, '38_demand_train': 115.0, '39_demand_train': 115.0, '40_demand_train': 115.0, '41_demand_train': 98.5, '42_demand_train': 85.9, '43_demand_train': 93.8, '44_demand_train': 115.0, '45_demand_train': 115.8, '46_demand_train': 115.0, '47_demand_train': 115.0, '48_demand_train': 94.4, '49_demand_train': 59.5, '50_demand_train': 74.4, '51_demand_train': 114.2, '52_demand_train': 113.5, '53_demand_train': 115.0, '54_demand_train': 115.8, '55_demand_train': 98.2, '56_demand_train': 86.5, '57_demand_train': 95.3, '58_demand_train': 114.0, '59_demand_train': 114.2, '60_demand_train': 114.2, '61_demand_train': 113.5, '62_demand_train': 83.0, '63_demand_train': 59.5, '64_demand_train': 66.7, '65_demand_train': 99.9, '66_demand_train': 100.2, '67_demand_train': 99.5, '68_demand_train': 99.5, '69_demand_train': 76.7, '70_demand_train': 59.0, '71_demand_train': 62.8, '72_demand_train': 139.9, '73_demand_train': 110.9, '74_demand_train': 102.3, '75_demand_train': 100.2, '76_demand_train': 77.9, '77_demand_train': 60.0, '78_demand_train': 63.3, '79_demand_train': 85.3, '80_demand_train': 85.9, '81_demand_train': 86.5, '82_demand_train': 87.8, '83_demand_train': 71.7, '84_demand_train': 60.0, '85_demand_train': 63.9, '86_demand_train': 106.5, '87_demand_train': 107.9, '88_demand_train': 105.2, '89_demand_train': 105.1, '90_demand_train': 81.3, '91_demand_train': 61.0, '92_demand_train': 61.5, '93_demand_train': 71.2, '94_demand_train': 106.3, '95_demand_train': 106.5, '96_demand_train': 106.5, '97_demand_train': 82.2, '98_demand_train': 61.0, '99_demand_train': 69.4, '100_demand_train': 106.9, '101_demand_train': 116.2, '102_demand_train': 116.6, '103_demand_train': 115.8, '104_demand_train': 98.3, '105_demand_train': 85.3, '106_demand_train': 89.5, '107_demand_train': 136.0, '108_demand_train': 138.3, '109_demand_train': 137.5, '110_demand_train': 138.3, '111_demand_train': 136.0, '112_demand_train': 136.7, '113_demand_train': 138.3, '114_demand_train': 135.4, '115_demand_train': 165.5, '116_demand_train': 197.7, '117_demand_train': 201.2, '118_demand_train': 180.7, '119_demand_train': 196.8, '120_demand_train': 225.4, '121_demand_train': 261.6, '122_demand_train': 284.7, '123_demand_train': 309.5, '124_demand_train': 310.6, '125_demand_train': 291.6, '126_demand_train': 283.5, '127_demand_train': 349.6, '128_demand_train': 341.8, '129_demand_train': 276.0, '130_demand_train': 278.1, '131_demand_train': 311.0, '132_demand_train': 321.1, '133_demand_train': 322.2, '134_demand_train': 458.6, '135_demand_train': 577.9, '136_demand_train': 624.5, '137_demand_train': 614.7, '138_demand_train': 595.8, '139_demand_train': 567.3, '140_demand_train': 547.7, '141_demand_train': 640.7, '142_demand_train': 719.3, '143_demand_train': 736.7, '144_demand_train': 718.3, '145_demand_train': 686.6, '146_demand_train': 647.5, '147_demand_train': 613.7, '148_demand_train': 577.9, '149_demand_train': 543.7, '150_demand_train': 512.3, '151_demand_train': 484.9, '152_demand_trai ...
# {'year_demand_train': 1981, '0_demand_train': 69.0, '1_demand_train': 70.0, '2_demand_train': 70.0, '3_demand_train': 71.0, '4_demand_train': 85.0, '5_demand_train': 85.0, '6_demand_train': 85.0, '7_demand_train': 85.0, '8_demand_train': 81.0, '9_demand_train': 72.0, '10_demand_train': 75.0, '11_demand_train': 86.0, '12_demand_train': 86.0, '13_demand_train': 86.0, '14_demand_train': 86.0, '15_demand_train': 77.0, '16_demand_train': 71.0, '17_demand_train': 71.0, '18_demand_train': 85.0, '19_demand_train': 85.0, '20_demand_train': 85.0, '21_demand_train': 85.0, '22_demand_train': 76.0, '23_demand_train': 70.0, '24_demand_train': 71.0, '25_demand_train': 85.0, '26_demand_train': 85.0, '27_demand_train': 85.0, '28_demand_train': 85.0, '29_demand_train': 76.0, '30_demand_train': 70.0, '31_demand_train': 71.0, '32_demand_train': 85.0, '33_demand_train': 86.0, '34_demand_train': 86.0, '35_demand_train': 86.0, '36_demand_train': 77.0, '37_demand_train': 71.0, '38_demand_train': 72.0, '39_demand_train': 85.0, '40_demand_train': 85.0, '41_demand_train': 85.0, '42_demand_train': 85.0, '43_demand_train': 77.0, '44_demand_train': 71.0, '45_demand_train': 71.0, '46_demand_train': 76.0, '47_demand_train': 75.0, '48_demand_train': 75.0, '49_demand_train': 75.0, '50_demand_train': 75.0, '51_demand_train': 75.0, '52_demand_train': 75.0, '53_demand_train': 74.0, '54_demand_train': 74.0, '55_demand_train': 74.0, '56_demand_train': 74.0, '57_demand_train': 75.0, '58_demand_train': 74.0, '59_demand_train': 74.0, '60_demand_train': 74.0, '61_demand_train': 74.0, '62_demand_train': 76.0, '63_demand_train': 76.0, '64_demand_train': 66.0, '65_demand_train': 60.0, '66_demand_train': 60.0, '67_demand_train': 59.0, '68_demand_train': 59.0, '69_demand_train': 59.0, '70_demand_train': 59.0, '71_demand_train': 54.0, '72_demand_train': 50.0, '73_demand_train': 57.0, '74_demand_train': 61.0, '75_demand_train': 66.0, '76_demand_train': 70.0, '77_demand_train': 70.0, '78_demand_train': 59.0, '79_demand_train': 51.0, '80_demand_train': 61.0, '81_demand_train': 69.0, '82_demand_train': 69.0, '83_demand_train': 69.0, '84_demand_train': 69.0, '85_demand_train': 59.0, '86_demand_train': 51.0, '87_demand_train': 62.0, '88_demand_train': 73.0, '89_demand_train': 81.0, '90_demand_train': 104.0, '91_demand_train': 130.0, '92_demand_train': 138.0, '93_demand_train': 137.0, '94_demand_train': 137.0, '95_demand_train': 137.0, '96_demand_train': 125.0, '97_demand_train': 115.0, '98_demand_train': 117.0, '99_demand_train': 117.0, '100_demand_train': 117.0, '101_demand_train': 117.0, '102_demand_train': 117.0, '103_demand_train': 116.0, '104_demand_train': 121.0, '105_demand_train': 126.0, '106_demand_train': 126.0, '107_demand_train': 126.0, '108_demand_train': 126.0, '109_demand_train': 125.0, '110_demand_train': 124.0, '111_demand_train': 134.0, '112_demand_train': 140.0, '113_demand_train': 140.0, '114_demand_train': 139.0, '115_demand_train': 168.0, '116_demand_train': 171.0, '117_demand_train': 190.0, '118_demand_train': 182.0, '119_demand_train': 124.0, '120_demand_train': 114.0, '121_demand_train': 101.0, '122_demand_train': 92.0, '123_demand_train': 92.0, '124_demand_train': 92.0, '125_demand_train': 91.0, '126_demand_train': 91.0, '127_demand_train': 86.0, '128_demand_train': 81.0, '129_demand_train': 82.0, '130_demand_train': 91.0, '131_demand_train': 92.0, '132_demand_train': 93.0, '133_demand_train': 123.0, '134_demand_train': 126.0, '135_demand_train': 126.0, '136_demand_train': 125.0, '137_demand_train': 122.0, '138_demand_train': 104.0, '139_demand_train': 89.0, '140_demand_train': 89.0, '141_demand_train': 89.0, '142_demand_train': 106.0, '143_demand_train': 132.0, '144_demand_train': 199.0, '145_demand_train': 473.0, '146_demand_train': 588.0, '147_demand_train': 584.0, '148_demand_train': 554.0, '149_demand_train': 522.0, '150_demand_train': 490.0, '151_demand_train': 402.0, '152_demand_train': 346.0, '153_demand_train': 337.0, '154_demand_train': 436.0, ' ...
# {'year_demand_train': 1980, '0_demand_train': 107.0, '1_demand_train': 138.0, '2_demand_train': 137.0, '3_demand_train': 125.0, '4_demand_train': 117.0, '5_demand_train': 118.0, '6_demand_train': 138.0, '7_demand_train': 138.0, '8_demand_train': 137.0, '9_demand_train': 137.0, '10_demand_train': 106.0, '11_demand_train': 85.0, '12_demand_train': 101.0, '13_demand_train': 124.0, '14_demand_train': 118.0, '15_demand_train': 139.0, '16_demand_train': 139.0, '17_demand_train': 108.0, '18_demand_train': 86.0, '19_demand_train': 103.0, '20_demand_train': 136.0, '21_demand_train': 137.0, '22_demand_train': 137.0, '23_demand_train': 137.0, '24_demand_train': 124.0, '25_demand_train': 116.0, '26_demand_train': 116.0, '27_demand_train': 144.0, '28_demand_train': 144.0, '29_demand_train': 144.0, '30_demand_train': 145.0, '31_demand_train': 110.0, '32_demand_train': 85.0, '33_demand_train': 103.0, '34_demand_train': 144.0, '35_demand_train': 144.0, '36_demand_train': 144.0, '37_demand_train': 145.0, '38_demand_train': 113.0, '39_demand_train': 85.0, '40_demand_train': 101.0, '41_demand_train': 144.0, '42_demand_train': 144.0, '43_demand_train': 144.0, '44_demand_train': 143.0, '45_demand_train': 108.0, '46_demand_train': 84.0, '47_demand_train': 105.0, '48_demand_train': 145.0, '49_demand_train': 144.0, '50_demand_train': 144.0, '51_demand_train': 143.0, '52_demand_train': 113.0, '53_demand_train': 87.0, '54_demand_train': 103.0, '55_demand_train': 137.0, '56_demand_train': 136.0, '57_demand_train': 137.0, '58_demand_train': 136.0, '59_demand_train': 108.0, '60_demand_train': 86.0, '61_demand_train': 103.0, '62_demand_train': 137.0, '63_demand_train': 137.0, '64_demand_train': 137.0, '65_demand_train': 136.0, '66_demand_train': 111.0, '67_demand_train': 86.0, '68_demand_train': 87.0, '69_demand_train': 114.0, '70_demand_train': 103.0, '71_demand_train': 101.0, '72_demand_train': 101.0, '73_demand_train': 105.0, '74_demand_train': 100.0, '75_demand_train': 100.0, '76_demand_train': 115.0, '77_demand_train': 117.0, '78_demand_train': 117.0, '79_demand_train': 119.0, '80_demand_train': 109.0, '81_demand_train': 101.0, '82_demand_train': 103.0, '83_demand_train': 132.0, '84_demand_train': 139.0, '85_demand_train': 138.0, '86_demand_train': 137.0, '87_demand_train': 117.0, '88_demand_train': 102.0, '89_demand_train': 113.0, '90_demand_train': 138.0, '91_demand_train': 138.0, '92_demand_train': 138.0, '93_demand_train': 138.0, '94_demand_train': 117.0, '95_demand_train': 101.0, '96_demand_train': 100.0, '97_demand_train': 111.0, '98_demand_train': 138.0, '99_demand_train': 137.0, '100_demand_train': 138.0, '101_demand_train': 116.0, '102_demand_train': 102.0, '103_demand_train': 112.0, '104_demand_train': 137.0, '105_demand_train': 137.0, '106_demand_train': 137.0, '107_demand_train': 137.0, '108_demand_train': 137.0, '109_demand_train': 136.0, '110_demand_train': 136.0, '111_demand_train': 135.0, '112_demand_train': 134.0, '113_demand_train': 137.0, '114_demand_train': 124.0, '115_demand_train': 115.0, '116_demand_train': 113.0, '117_demand_train': 114.0, '118_demand_train': 123.0, '119_demand_train': 102.0, '120_demand_train': 89.0, '121_demand_train': 80.0, '122_demand_train': 80.0, '123_demand_train': 80.0, '124_demand_train': 81.0, '125_demand_train': 82.0, '126_demand_train': 83.0, '127_demand_train': 80.0, '128_demand_train': 82.0, '129_demand_train': 84.0, '130_demand_train': 80.0, '131_demand_train': 80.0, '132_demand_train': 85.0, '133_demand_train': 86.0, '134_demand_train': 99.0, '135_demand_train': 103.0, '136_demand_train': 104.0, '137_demand_train': 101.0, '138_demand_train': 101.0, '139_demand_train': 114.0, '140_demand_train': 116.0, '141_demand_train': 117.0, '142_demand_train': 117.0, '143_demand_train': 117.0, '144_demand_train': 117.0, '145_demand_train': 117.0, '146_demand_train': 117.0, '147_demand_train': 115.0, '148_demand_train': 115.0, '149_demand_train': 120.0, '150_demand_train': 117.0, '151_demand_train': 117.0, '1 ...
# {'year_demand_train': 1967, '0_demand_train': 106.0, '1_demand_train': 106.0, '2_demand_train': 106.0, '3_demand_train': 105.0, '4_demand_train': 105.0, '5_demand_train': 105.0, '6_demand_train': 103.0, '7_demand_train': 108.0, '8_demand_train': 127.0, '9_demand_train': 137.0, '10_demand_train': 137.0, '11_demand_train': 136.0, '12_demand_train': 135.0, '13_demand_train': 117.0, '14_demand_train': 110.0, '15_demand_train': 109.0, '16_demand_train': 121.0, '17_demand_train': 130.0, '18_demand_train': 129.0, '19_demand_train': 129.0, '20_demand_train': 114.0, '21_demand_train': 109.0, '22_demand_train': 127.0, '23_demand_train': 130.0, '24_demand_train': 129.0, '25_demand_train': 129.0, '26_demand_train': 131.0, '27_demand_train': 117.0, '28_demand_train': 112.0, '29_demand_train': 131.0, '30_demand_train': 131.0, '31_demand_train': 130.0, '32_demand_train': 129.0, '33_demand_train': 130.0, '34_demand_train': 116.0, '35_demand_train': 110.0, '36_demand_train': 129.0, '37_demand_train': 129.0, '38_demand_train': 130.0, '39_demand_train': 128.0, '40_demand_train': 130.0, '41_demand_train': 114.0, '42_demand_train': 108.0, '43_demand_train': 128.0, '44_demand_train': 130.0, '45_demand_train': 129.0, '46_demand_train': 129.0, '47_demand_train': 120.0, '48_demand_train': 111.0, '49_demand_train': 109.0, '50_demand_train': 109.0, '51_demand_train': 110.0, '52_demand_train': 110.0, '53_demand_train': 109.0, '54_demand_train': 108.0, '55_demand_train': 110.0, '56_demand_train': 111.0, '57_demand_train': 109.0, '58_demand_train': 109.0, '59_demand_train': 108.0, '60_demand_train': 109.0, '61_demand_train': 108.0, '62_demand_train': 108.0, '63_demand_train': 108.0, '64_demand_train': 109.0, '65_demand_train': 110.0, '66_demand_train': 111.0, '67_demand_train': 111.0, '68_demand_train': 114.0, '69_demand_train': 113.0, '70_demand_train': 112.0, '71_demand_train': 127.0, '72_demand_train': 135.0, '73_demand_train': 128.0, '74_demand_train': 125.0, '75_demand_train': 102.0, '76_demand_train': 60.0, '77_demand_train': 86.0, '78_demand_train': 111.0, '79_demand_train': 121.0, '80_demand_train': 132.0, '81_demand_train': 132.0, '82_demand_train': 131.0, '83_demand_train': 130.0, '84_demand_train': 130.0, '85_demand_train': 129.0, '86_demand_train': 130.0, '87_demand_train': 130.0, '88_demand_train': 130.0, '89_demand_train': 131.0, '90_demand_train': 130.0, '91_demand_train': 129.0, '92_demand_train': 130.0, '93_demand_train': 130.0, '94_demand_train': 129.0, '95_demand_train': 130.0, '96_demand_train': 130.0, '97_demand_train': 130.0, '98_demand_train': 137.0, '99_demand_train': 133.0, '100_demand_train': 145.0, '101_demand_train': 151.0, '102_demand_train': 148.0, '103_demand_train': 147.0, '104_demand_train': 147.0, '105_demand_train': 157.0, '106_demand_train': 160.0, '107_demand_train': 161.0, '108_demand_train': 161.0, '109_demand_train': 161.0, '110_demand_train': 160.0, '111_demand_train': 164.0, '112_demand_train': 163.0, '113_demand_train': 162.0, '114_demand_train': 161.0, '115_demand_train': 160.0, '116_demand_train': 161.0, '117_demand_train': 160.0, '118_demand_train': 158.0, '119_demand_train': 157.0, '120_demand_train': 159.0, '121_demand_train': 164.0, '122_demand_train': 168.0, '123_demand_train': 169.0, '124_demand_train': 167.0, '125_demand_train': 167.0, '126_demand_train': 167.0, '127_demand_train': 167.0, '128_demand_train': 167.0, '129_demand_train': 167.0, '130_demand_train': 167.0, '131_demand_train': 166.0, '132_demand_train': 169.0, '133_demand_train': 171.0, '134_demand_train': 172.0, '135_demand_train': 170.0, '136_demand_train': 190.0, '137_demand_train': 202.0, '138_demand_train': 206.0, '139_demand_train': 207.0, '140_demand_train': 207.0, '141_demand_train': 207.0, '142_demand_train': 209.0, '143_demand_train': 224.0, '144_demand_train': 226.0, '145_demand_train': 226.0, '146_demand_train': 226.0, '147_demand_train': 226.0, '148_demand_train': 226.0, '149_demand_train': 275.0, '150_demand_train': 286.0, '151_de ...

# %%
records.dataset
# Out:
# Dataset(jsonld='metadata_dam.json', operations=OperationGraph(issues=Issues(_errors=set(), _warnings={('Property "https://schema.org/version" is recommended, but does not exist.', Metadata(uuid="_:N2f4cafbc19bb49ba8a5cf11f40ce7324")), ('Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.', Metadata(uuid="_:N2f4cafbc19bb49ba8a5cf11f40ce7324")), ('Property "https://schema.org/datePublished" is recommended, but does not exist.', Metadata(uuid="_:N2f4cafbc19bb49ba8a5cf11f40ce7324"))}), operations=<mlcroissant._src.operation_graph.base_operation.Operations object at 0x30b6b8080>), metadata=Metadata(uuid="_:N2f4cafbc19bb49ba8a5cf11f40ce7324"), debug=False, mapping=None)

# %%
import pandas as pd

df = pd.DataFrame.from_records([r for r in records])
df.head()
# Out:
#    year_demand_train  0_demand_train  1_demand_train  2_demand_train  \
# 0               1985           84.30          113.60          113.90
# 1               1959           99.00           99.00           99.00
# 2               1997          140.30          139.70          139.80
# 3               2008           45.28           45.04           45.22
# 4               2006           44.98           44.53           40.43
#
#    3_demand_train  4_demand_train  5_demand_train  6_demand_train  \
# 0           96.60           83.00           83.10           98.50
# 1          100.00           99.00           99.00          122.00
# 2          140.30          139.20          138.50          138.50
# 3           45.34           45.84           45.89           45.80
# 4           37.51           36.80           36.67           36.56
#
#    7_demand_train  8_demand_train  ...  356_demand_train  357_demand_train  \
# 0           98.70           98.70  ...             59.30             59.30
# 1          122.00          122.00  ...            120.00            121.00
# 2          138.50          138.50  ...            109.80            109.90
# 3           50.58           50.87  ...            154.11            151.41
# 4           36.40           36.48  ...             99.87             99.27
#
#    358_demand_train  359_demand_train  360_demand_train  361_demand_train  \
# 0             59.50             59.20             59.30             60.30
# 1            119.00            119.00            118.00            120.00
# 2            109.40            103.50            100.20             99.50
# 3            136.46            134.77            134.32            134.82
# 4             99.19             99.50             99.28             86.26
#
#    362_demand_train  363_demand_train  364_demand_train  365_demand_train
# 0             60.90             60.90             60.90               NaN
# 1            119.00            119.00            119.00               NaN
# 2             99.20             99.20            100.70               NaN
# 3            135.13            134.37            134.25            134.53
# 4             85.03             84.97             84.66               NaN
#
# [5 rows x 367 columns]
