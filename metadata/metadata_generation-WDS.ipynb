# %% [markdown]
# # Tutorial for `mlcroissant` 🥐

# %% [markdown]
# ## Introduction
#
# Croissant 🥐 is a high-level format for machine learning datasets that combines metadata, resource file descriptions, data structure, and default ML semantics into a single file.
#
# Croissant builds on schema.org, and its `sc:Dataset` vocabulary, a widely used format to represent datasets on the Web, and make them searchable.
#
# The [`mlcroissant`](https://github.com/mlcommons/croissant/python/mlcroissant) Python library empowers developers to interact with Croissant:
#
# - Programmatically write your JSON-LD Croissant files.
# - Verify your JSON-LD Croissant files.
# - Load data from Croissant datasets.

# %%
# # Install mlcroissant from the source
# !brew install -y python3-dev graphviz libgraphviz-dev pkg-config
# !pip install "git+https://github.com/${GITHUB_REPOSITORY:-mlcommons/croissant}.git@${GITHUB_HEAD_REF:-main}#subdirectory=python/mlcroissant&egg=mlcroissant[dev]"

# %%
import mlcroissant as mlc
import hashlib
import json

# %%
# DEMAND
test_demand = "gym4real/data/wds/demand/datasets/test1000.csv"

with open(test_demand, "rb") as f:
    sha256_hash_test_demand = hashlib.sha256(f.read()).hexdigest()

# %%
# FileObjects and FileSets define the resources of the dataset.
distribution = [
    mlc.FileObject(
        id="github-repository",
        name="github-repository",
        description="Gym4ReaL repository on GitHub.",
        content_url="https://github.com/Daveonwave/gym4ReaL",
        encoding_formats=["git+https"],
        sha256="main",
    ),
    mlc.FileObject(
        id="demand_test",
        name="demand_test",
        description="Demand patterns (test set)",
        content_url="https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/" + test_demand,
        encoding_formats=["text/csv"],
        sha256=sha256_hash_test_demand,
    ),
    mlc.FileSet(
        id="demand_train",
        name="demand_train",
        description="Train demand patterns files",
        encoding_formats=["text/csv"],
        contained_in=["github-repository"],
        includes="gym4real/data/wds/demand/datasets/interval_*.csv",
    ),
]

# %%
# --- DEMAND TRAIN ---
train_demand_fields = []

for i in range(54):
    train_demand_fields.append(
        mlc.Field(
            id= 'train_' + str(i),
            name=str(i),
            description=f"Demand pattern of a week within a year (train set)",
            data_types=mlc.DataType.FLOAT,
            source=mlc.Source(
                        file_set="demand_train",
                        # file_object='github-repository',
                        # Extract the field from the column of a FileObject/FileSet:
                        extract=mlc.Extract(column=str(i)))))

# --- DEMAND TEST ---
test_demand_fields = []

for i in range(1000):
    test_demand_fields.append(
        mlc.Field(
            id='test_' + str(i),
            name=str(i),
            description=f"Demand pattern of a week within a year (test set)",
            data_types=mlc.DataType.FLOAT,
            source=mlc.Source(
                        file_object="demand_test",
                        # file_object='github-repository',
                        # Extract the field from the column of a FileObject/FileSet:
                        extract=mlc.Extract(column=str(i)))))

# %%
record_sets = [
    mlc.RecordSet(
        id="demand_pattern_train",
        name="demand_pattern_train",
        # Each record has one or many fields...
        fields=train_demand_fields,
    ),
    mlc.RecordSet(
        id="demand_pattern_test",
        name="demand_pattern_test",
        # Each record has one or many fields...
        fields=test_demand_fields,
    ),
]

# Metadata contains information about the dataset.
metadata = mlc.Metadata(
    name="wds_data",
    # Descriptions can contain plain text or markdown.
    description=(
        "Water Distribution System 'Anutown' demand pattern data (train and test)."
    ),
    # cite_as=(
    #     "@article{brown2020language, title={Language Models are Few-Shot"
    # ),
    url="https://github.com/Daveonwave/gym4ReaL",
    license="https://creativecommons.org/licenses/by/4.0/",
    distribution=distribution,
    record_sets=record_sets,
)

# %%
print(metadata.issues.report())
# Out:
# Found the following 3 warning(s) during the validation:
#   -  [Metadata(wds_data)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
#   -  [Metadata(wds_data)] Property "https://schema.org/datePublished" is recommended, but does not exist.
#   -  [Metadata(wds_data)] Property "https://schema.org/version" is recommended, but does not exist.

# %%
with open("metadata_WDS.json", "w") as f:
  content = metadata.to_json()
  content = json.dumps(content, indent=2)
  print(content)
  f.write(content)
  f.write("\n")  # Terminate file with newline
# Out:
# {
#   "@context": {
#     "@language": "en",
#     "@vocab": "https://schema.org/",
#     "citeAs": "cr:citeAs",
#     "column": "cr:column",
#     "conformsTo": "dct:conformsTo",
#     "cr": "http://mlcommons.org/croissant/",
#     "rai": "http://mlcommons.org/croissant/RAI/",
#     "data": {
#       "@id": "cr:data",
#       "@type": "@json"
#     },
#     "dataType": {
#       "@id": "cr:dataType",
#       "@type": "@vocab"
#     },
#     "dct": "http://purl.org/dc/terms/",
#     "examples": {
#       "@id": "cr:examples",
#       "@type": "@json"
#     },
#     "extract": "cr:extract",
#     "field": "cr:field",
#     "fileProperty": "cr:fileProperty",
#     "fileObject": "cr:fileObject",
#     "fileSet": "cr:fileSet",
#     "format": "cr:format",
#     "includes": "cr:includes",
#     "isLiveDataset": "cr:isLiveDataset",
#     "jsonPath": "cr:jsonPath",
#     "key": "cr:key",
#     "md5": "cr:md5",
#     "parentField": "cr:parentField",
#     "path": "cr:path",
#     "recordSet": "cr:recordSet",
#     "references": "cr:references",
#     "regex": "cr:regex",
#     "repeated": "cr:repeated",
#     "replace": "cr:replace",
#     "sc": "https://schema.org/",
#     "separator": "cr:separator",
#     "source": "cr:source",
#     "subField": "cr:subField",
#     "transform": "cr:transform"
#   },
#   "@type": "sc:Dataset",
#   "name": "wds_data",
#   "description": "Water Distribution System 'Anutown' demand pattern data (train and test).",
#   "conformsTo": "http://mlcommons.org/croissant/1.0",
#   "license": "https://creativecommons.org/licenses/by/4.0/",
#   "url": "https://github.com/Daveonwave/gym4ReaL",
#   "distribution": [
#     {
#       "@type": "cr:FileObject",
#       "@id": "github-repository",
#       "name": "github-repository",
#       "description": "Gym4ReaL repository on GitHub.",
#       "contentUrl": "https://github.com/Daveonwave/gym4ReaL",
#       "encodingFormat": "git+https",
#       "sha256": "main"
#     },
#     {
#       "@type": "cr:FileObject",
#       "@id": "demand_test",
#       "name": "demand_test",
#       "description": "Demand patterns (test set)",
#       "contentUrl": "https://raw.githubusercontent.com/Daveonwave/gym4ReaL/main/gym4real/data/wds/demand/datasets/test1000.csv",
#       "encodingFormat": "text/csv",
#       "sha256": "71defc2fe3263216213c327868b637c7db3d2bc0bedcbaac43b1c6249e60d4aa"
#     },
#     {
#       "@type": "cr:FileSet",
#       "@id": "demand_train",
#       "name": "demand_train",
#       "description": "Train demand patterns files",
#       "containedIn": {
#         "@id": "github-repository"
#       },
#       "encodingFormat": "text/csv",
#       "includes": "gym4real/data/wds/demand/datasets/interval_*.csv"
#     }
#   ],
#   "recordSet": [
#     {
#       "@type": "cr:RecordSet",
#       "@id": "demand_pattern_train",
#       "name": "demand_pattern_train",
#       "field": [
#         {
#           "@type": "cr:Field",
#           "@id": "train_0",
#           "name": "0",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "0"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_1",
#           "name": "1",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "1"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_2",
#           "name": "2",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "2"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_3",
#           "name": "3",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "3"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_4",
#           "name": "4",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "4"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_5",
#           "name": "5",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "5"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_6",
#           "name": "6",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "6"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_7",
#           "name": "7",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "7"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_8",
#           "name": "8",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "8"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_9",
#           "name": "9",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "9"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_10",
#           "name": "10",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "10"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_11",
#           "name": "11",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "11"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_12",
#           "name": "12",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "12"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_13",
#           "name": "13",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "13"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_14",
#           "name": "14",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "14"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_15",
#           "name": "15",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "15"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_16",
#           "name": "16",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "16"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_17",
#           "name": "17",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "17"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_18",
#           "name": "18",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "18"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_19",
#           "name": "19",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "19"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_20",
#           "name": "20",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "20"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_21",
#           "name": "21",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "21"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_22",
#           "name": "22",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "22"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_23",
#           "name": "23",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "23"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_24",
#           "name": "24",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "24"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_25",
#           "name": "25",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "25"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_26",
#           "name": "26",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "26"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_27",
#           "name": "27",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "27"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_28",
#           "name": "28",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "28"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_29",
#           "name": "29",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "29"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_30",
#           "name": "30",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "30"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_31",
#           "name": "31",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "31"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_32",
#           "name": "32",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "32"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_33",
#           "name": "33",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "33"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_34",
#           "name": "34",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "34"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_35",
#           "name": "35",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "35"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_36",
#           "name": "36",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "36"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_37",
#           "name": "37",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "37"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_38",
#           "name": "38",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "38"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_39",
#           "name": "39",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "39"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_40",
#           "name": "40",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "40"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_41",
#           "name": "41",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "41"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_42",
#           "name": "42",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "42"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_43",
#           "name": "43",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "43"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_44",
#           "name": "44",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "44"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_45",
#           "name": "45",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "45"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_46",
#           "name": "46",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "46"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_47",
#           "name": "47",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "47"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_48",
#           "name": "48",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "48"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_49",
#           "name": "49",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "49"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_50",
#           "name": "50",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "50"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_51",
#           "name": "51",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "51"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_52",
#           "name": "52",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "52"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "train_53",
#           "name": "53",
#           "description": "Demand pattern of a week within a year (train set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileSet": {
#               "@id": "demand_train"
#             },
#             "extract": {
#               "column": "53"
#             }
#           }
#         }
#       ]
#     },
#     {
#       "@type": "cr:RecordSet",
#       "@id": "demand_pattern_test",
#       "name": "demand_pattern_test",
#       "field": [
#         {
#           "@type": "cr:Field",
#           "@id": "test_0",
#           "name": "0",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "0"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_1",
#           "name": "1",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "1"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_2",
#           "name": "2",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "2"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_3",
#           "name": "3",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "3"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_4",
#           "name": "4",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "4"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_5",
#           "name": "5",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "5"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_6",
#           "name": "6",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "6"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_7",
#           "name": "7",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "7"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_8",
#           "name": "8",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "8"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_9",
#           "name": "9",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "9"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_10",
#           "name": "10",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "10"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_11",
#           "name": "11",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "11"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_12",
#           "name": "12",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "12"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_13",
#           "name": "13",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "13"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_14",
#           "name": "14",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "14"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_15",
#           "name": "15",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "15"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_16",
#           "name": "16",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "16"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_17",
#           "name": "17",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "17"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_18",
#           "name": "18",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "18"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_19",
#           "name": "19",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "19"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_20",
#           "name": "20",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "20"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_21",
#           "name": "21",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "21"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_22",
#           "name": "22",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "22"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_23",
#           "name": "23",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "23"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_24",
#           "name": "24",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "24"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_25",
#           "name": "25",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "25"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_26",
#           "name": "26",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "26"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_27",
#           "name": "27",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "27"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_28",
#           "name": "28",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "28"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_29",
#           "name": "29",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "29"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_30",
#           "name": "30",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "30"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_31",
#           "name": "31",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "31"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_32",
#           "name": "32",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "32"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_33",
#           "name": "33",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "33"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_34",
#           "name": "34",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "34"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_35",
#           "name": "35",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "35"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_36",
#           "name": "36",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "36"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_37",
#           "name": "37",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "37"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_38",
#           "name": "38",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "38"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_39",
#           "name": "39",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "39"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_40",
#           "name": "40",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "40"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_41",
#           "name": "41",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "41"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_42",
#           "name": "42",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "42"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_43",
#           "name": "43",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "43"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_44",
#           "name": "44",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "44"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_45",
#           "name": "45",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "45"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_46",
#           "name": "46",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "46"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_47",
#           "name": "47",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "47"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_48",
#           "name": "48",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "48"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_49",
#           "name": "49",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "49"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_50",
#           "name": "50",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "50"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_51",
#           "name": "51",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "51"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_52",
#           "name": "52",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "52"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_53",
#           "name": "53",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "53"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_54",
#           "name": "54",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "54"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_55",
#           "name": "55",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "55"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_56",
#           "name": "56",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "56"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_57",
#           "name": "57",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "57"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_58",
#           "name": "58",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "58"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_59",
#           "name": "59",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "59"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
# ...
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_960",
#           "name": "960",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "960"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_961",
#           "name": "961",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "961"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_962",
#           "name": "962",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "962"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_963",
#           "name": "963",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "963"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_964",
#           "name": "964",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "964"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_965",
#           "name": "965",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "965"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_966",
#           "name": "966",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "966"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_967",
#           "name": "967",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "967"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_968",
#           "name": "968",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "968"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_969",
#           "name": "969",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "969"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_970",
#           "name": "970",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "970"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_971",
#           "name": "971",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "971"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_972",
#           "name": "972",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "972"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_973",
#           "name": "973",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "973"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_974",
#           "name": "974",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "974"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_975",
#           "name": "975",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "975"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_976",
#           "name": "976",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "976"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_977",
#           "name": "977",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "977"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_978",
#           "name": "978",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "978"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_979",
#           "name": "979",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "979"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_980",
#           "name": "980",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "980"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_981",
#           "name": "981",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "981"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_982",
#           "name": "982",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "982"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_983",
#           "name": "983",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "983"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_984",
#           "name": "984",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "984"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_985",
#           "name": "985",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "985"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_986",
#           "name": "986",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "986"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_987",
#           "name": "987",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "987"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_988",
#           "name": "988",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "988"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_989",
#           "name": "989",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "989"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_990",
#           "name": "990",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "990"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_991",
#           "name": "991",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "991"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_992",
#           "name": "992",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "992"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_993",
#           "name": "993",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "993"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_994",
#           "name": "994",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "994"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_995",
#           "name": "995",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "995"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_996",
#           "name": "996",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "996"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_997",
#           "name": "997",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "997"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_998",
#           "name": "998",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "998"
#             }
#           }
#         },
#         {
#           "@type": "cr:Field",
#           "@id": "test_999",
#           "name": "999",
#           "description": "Demand pattern of a week within a year (test set)",
#           "dataType": "sc:Float",
#           "source": {
#             "fileObject": {
#               "@id": "demand_test"
#             },
#             "extract": {
#               "column": "999"
#             }
#           }
#         }
#       ]
#     }
#   ]
# }

# %%
dataset = mlc.Dataset(jsonld="metadata_WDS.json")
# Out:
# WARNING:absl:Found the following 3 warning(s) during the validation:
#   -  [Metadata(wds_data)] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.
#   -  [Metadata(wds_data)] Property "https://schema.org/datePublished" is recommended, but does not exist.
#   -  [Metadata(wds_data)] Property "https://schema.org/version" is recommended, but does not exist.

# %% [markdown]
# ...and yield records from this dataset:

# %%
records = dataset.records(record_set="demand_pattern_train")

for i, record in enumerate(records):
  print(record)
  if i > 10:
    break
# Out:
# {'train_0': 0.0263059516896281, 'train_1': 0.0507741118009319, 'train_2': 0.0264841291985131, 'train_3': 0.0242795299314405, 'train_4': 0.0261226765121758, 'train_5': 0.01671504745887, 'train_6': 0.0082237633889451, 'train_7': 0.0104343913386532, 'train_8': 0.0309155451515997, 'train_9': 0.0239738072883243, 'train_10': 0.0169113270651604, 'train_11': -0.0007399897782609, 'train_12': 0.0239447734971827, 'train_13': 0.0370419357907571, 'train_14': 0.0228664729933332, 'train_15': 0.0163147568791094, 'train_16': 0.0178869772234797, 'train_17': 0.0098753279829056, 'train_18': 0.0343250568171407, 'train_19': 0.0186230309622721, 'train_20': 0.0329460699050128, 'train_21': 0.034002015021041, 'train_22': 0.0403209054081022, 'train_23': 0.0219601085583627, 'train_24': 0.0181399773035339, 'train_25': 0.030884085415979, 'train_26': 0.0209436523094625, 'train_27': 0.0185719894297001, 'train_28': 0.0179164983875613, 'train_29': 0.0315279472381174, 'train_30': 0.0316867317247521, 'train_31': 0.0213802995077613, 'train_32': 0.0257466496035697, 'train_33': 0.0201895292290414, 'train_34': 0.0460255221544102, 'train_35': 0.030690353937003, 'train_36': 0.0392796520836218, 'train_37': 0.0152962631631564, 'train_38': 0.0190457675249181, 'train_39': 0.0375776056239238, 'train_40': 0.0173145753210462, 'train_41': 0.0099569719280902, 'train_42': 0.0364753741099015, 'train_43': 0.0331220716891615, 'train_44': 0.0315333993771626, 'train_45': 0.0398521631371033, 'train_46': 0.0201402961122351, 'train_47': 0.0204618519964061, 'train_48': 0.0062652169585671, 'train_49': 0.0458473113805485, 'train_50': 0.0269993446493477, 'train_51': -0.0045578715459644, 'train_52': 0.0360967279240226, 'train_53': 0.0225116116533328}
# {'train_0': 0.0167514475500423, 'train_1': 0.0103188898235159, 'train_2': 0.0017675701525928, 'train_3': 0.0124971874230132, 'train_4': 0.0029936339135082, 'train_5': 0.0105084036549365, 'train_6': 0.0114544341318509, 'train_7': -0.0041518518827666, 'train_8': -0.007819585247124, 'train_9': 0.0199742629985117, 'train_10': 0.003997821480996, 'train_11': 0.0076649651368172, 'train_12': 0.0198207544972336, 'train_13': 0.0082774841501497, 'train_14': 0.0024192217761005, 'train_15': 0.0137073227249868, 'train_16': 0.0129418767098885, 'train_17': 0.019705035057213, 'train_18': 0.0256553850545259, 'train_19': 0.0119008290859849, 'train_20': -0.0059961727475544, 'train_21': 0.0113815424447701, 'train_22': 0.0138758934812787, 'train_23': 0.0101174428044469, 'train_24':
# %%
import pandas as pd

pd.DataFrame.from_records(list(records))
# Out:
#        train_0   train_1   train_2   train_3   train_4   train_5   train_6  \
# 0     0.026306  0.050774  0.026484  0.024280  0.026123  0.016715  0.008224
# 1     0.016751  0.010319  0.001768  0.012497  0.002994  0.010508  0.011454
# 2     0.004875  0.013385  0.019027  0.024996  0.027797  0.011457  0.010905
# 3     0.021159  0.011407  0.005788  0.026918  0.010900  0.031438  0.026038
# 4     0.031284  0.035913  0.010201  0.014955  0.020589 -0.001218  0.016108
# ...        ...       ...       ...       ...       ...       ...       ...
# 5539  0.642907  0.610875  0.713977  0.568482  0.547551  0.599023  0.545045
# 5540  0.512012  0.564214  0.556908  0.505588  0.591297  0.565704  0.554468
# 5541  0.555436  0.517716  0.515272  0.518963  0.559871  0.501079  0.574604
# 5542  0.502079  0.548542  0.504645  0.468332  0.385093  0.499699  0.462575
# 5543  0.510850  0.455464  0.507023  0.515408  0.488486  0.585401  0.536348
#
#        train_7   train_8   train_9  ...  train_44  train_45  train_46  \
# 0     0.010434  0.030916  0.023974  ...  0.031533  0.039852  0.020140
# 1    -0.004152 -0.007820  0.019974  ...  0.029186  0.014953  0.024390
# 2    -0.002278  0.028342  0.005058  ...  0.008298  0.030901  0.003734
# 3     0.010626  0.028941  0.013072  ...  0.001920  0.013456  0.022301
# 4     0.021996  0.030372  0.036109  ...  0.021662  0.011421  0.021159
# ...        ...       ...       ...  ...       ...       ...       ...
# 5539  0.659483  0.664110  0.618589  ...  0.620095  0.711989  0.601223
# 5540  0.649790  0.560428  0.546584  ...  0.526727  0.603055  0.591176
# 5541  0.596186  0.565110  0.553670  ...  0.452269  0.527857  0.518052
# 5542  0.502673  0.481098  0.506005  ...  0.405953  0.441832  0.421683
# 5543  0.548128  0.632137  0.556012  ...  0.578503  0.561017  0.574650
#
#       train_47  train_48  train_49  train_50  train_51  train_52  train_53
# 0     0.020462  0.006265  0.045847  0.026999 -0.004558  0.036097  0.022512
# 1     0.006842  0.023565  0.007037 -0.001514  0.020469  0.012829  0.016945
# 2     0.027949  0.026256  0.006755  0.026708  0.000995  0.026634  0.002821
# 3     0.008879  0.029388  0.001208  0.023917  0.007627  0.035184  0.012492
# 4     0.029968  0.036582  0.043277  0.034045  0.023711  0.039454  0.034689
# ...        ...       ...       ...       ...       ...       ...       ...
# 5539  0.680003  0.627978  0.542115  0.629203  0.670349  0.675510  0.657331
# 5540  0.541517  0.570879  0.562715  0.620995  0.627673  0.600452  0.588287
# 5541  0.633685  0.654373  0.489990  0.528807  0.599134  0.516563  0.527317
# 5542  0.476084  0.469088  0.427968  0.500619  0.432514  0.457281  0.471290
# 5543  0.469542  0.525371  0.452002  0.553621  0.559667  0.607484  0.433637
#
# [5544 rows x 54 columns]
