# %% [markdown]
# # Tutorial for `mlcroissant` 🥐

# %% [markdown]
# ## Introduction
#
# Croissant 🥐 is a high-level format for machine learning datasets that combines metadata, resource file descriptions, data structure, and default ML semantics into a single file.
#
# Croissant builds on schema.org, and its `sc:Dataset` vocabulary, a widely used format to represent datasets on the Web, and make them searchable.
#
# The [`mlcroissant`](https://github.com/mlcommons/croissant/python/mlcroissant) Python library empowers developers to interact with Croissant:
#
# - Programmatically write your JSON-LD Croissant files.
# - Verify your JSON-LD Croissant files.
# - Load data from Croissant datasets.

# %%
# Install mlcroissant from the source
# !brew install -y python3-dev graphviz libgraphviz-dev pkg-config
# !pip install "git+https://github.com/${GITHUB_REPOSITORY:-mlcommons/croissant}.git@${GITHUB_HEAD_REF:-main}#subdirectory=python/mlcroissant&egg=mlcroissant[dev]"
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# anubis              ftxui               hjson               marmite
# apache-flink@1      gama                is-fast             mcpm
# chdig               gdown               libpg_query         mob
# dish                geesefs             lld@19              x-cmd
# easyeda2kicad       github-mcp-server   llvm@19             xan
# ente-cli            harsh               mani
# ==> New Casks
# atv-remote                 font-coral-pixels          rave
# bambu-connect              font-epunda-sans           repo-prompt
# beutl                      font-epunda-slab           restapia
# captainplugins             font-lxgw-wenkai-gb-lite   slidepad
# companion                  font-playpen-sans-deva     stability-matrix
# companion-satellite        grayjay                    swift-shift
# companion@beta             hamrs-pro                  vesktop
# dante-controller           inmusic-software-center    voiceink
# dante-via                  kilohearts-installer       yaak@beta
# earnapp                    moment
# font-adwaita               ndi-tools
#
# You have 21 outdated formulae and 2 outdated casks installed.
#
# Usage: brew install [options] formula|cask [...]
#
# Install a formula or cask. Additional options specific to a formula may be
# appended to the command.
#
# Unless $HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK is set, brew upgrade or brew
# reinstall will be run for outdated dependents and dependents with broken
# linkage, respectively.
#
# Unless $HOMEBREW_NO_INSTALL_CLEANUP is set, brew cleanup will then be run
# for the installed formulae or, every 30 days, for all formulae.
#
# Unless $HOMEBREW_NO_INSTALL_UPGRADE is set, brew install formula will
# upgrade formula if it is already installed but outdated.
#
#   -d, --debug                      If brewing fails, open an interactive
#                                    debugging session with access to IRB or a
#                                    shell inside the temporary build directory.
#       --display-times              Print install times for each package at the
#                                    end of the run.
#   -f, --force                      Install formulae without checking for
#                                    previously installed keg-only or non-migrated
#                                    versions. When installing casks, overwrite
#                                    existing files (binaries and symlinks are
#                                    excluded, unless originally from the same
#                                    cask).
#   -v, --verbose                    Print the verification and post-install
#                                    steps.
#   -n, --dry-run                    Show what would be installed, but do not
#                                    actually install anything.
#       --formula, --formulae        Treat all named arguments as formulae.
#       --ignore-dependencies        An unsupported Homebrew development option to
#                                    skip installing any dependencies of any kind.
#                                    If the dependencies are not already present,
#                                    the formula will have issues. If you're not
#                                    developing Homebrew, consider adjusting your
#                                    PATH rather than using this option.
#       --only-dependencies          Install the dependencies with specified
#                                    options but do not install the formula
#                                    itself.
#       --cc                         Attempt to compile using the specified
#                                    compiler, which should be the name of the
#                                    compiler's executable, e.g. gcc-9 for GCC
#                                    9. In order to use LLVM's clang, specify
#                                    llvm_clang. To use the Apple-provided
#                                    clang, specify clang. This option will only
#                                    accept compilers that are provided by
#                                    Homebrew or bundled with macOS. Please do not
#                                    file issues if you encounter errors while
#                                    using this option.
#   -s, --build-from-source          Compile formula from source even if a
#                                    bottle is provided. Dependencies will still
#                                    be installed from bottles if they are
#                                    available.
#       --force-bottle               Install from a bottle if it exists for the
#                                    current or newest version of macOS, even if
#                                    it would not normally be used for
#                                    installation.
#       --include-test               Install testing dependencies required to run
#                                    brew test formula.
#       --HEAD                       If formula defines it, install the HEAD
#                                    version, aka. main, trunk, unstable, master.
#       --fetch-HEAD                 Fetch the upstream repository to detect if
#                                    the HEAD installation of the formula is
#                                    outdated. Otherwise, the repository's HEAD
#                                    will only be checked for updates when a new
#                                    stable or development version has been
#                                    released.
#       --keep-tmp                   Retain the temporary files created during
#                                    installation.
#       --debug-symbols              Generate debug symbols on build. Source will
#                                    be retained in a cache directory.
#       --build-bottle               Prepare the formula for eventual bottling
#                                    during installation, skipping any
#                                    post-install steps.
#       --skip-post-install          Install but skip any post-install steps.
#       --skip-link                  Install but skip linking the keg into the
#                                    prefix.
#       --as-dependency              Install but mark as installed as a dependency
#                                    and not installed on request.
#       --bottle-arch                Optimise bottles for the specified
#                                    architecture rather than the oldest
#                                    architecture supported by the version of
#                                    macOS the bottles are built on.
#   -i, --interactive                Download and patch formula, then open a
#                                    shell. This allows the user to run
#                                    ./configure --help and otherwise determine
#                                    how to turn the software package into a
#                                    Homebrew package.
#   -g, --git                        Create a Git repository, useful for creating
#                                    patches to the software.
#       --overwrite                  Delete files that already exist in the prefix
#                                    while linking.
#       --ask                        Ask for confirmation before downloading and
#                                    installing formulae. Print bottles and
#                                    dependencies download size and install size.
#       --cask, --casks              Treat all named arguments as casks.
#       --[no-]binaries              Disable/enable linking of helper executables
#                                    (default: enabled).
#       --require-sha                Require all casks to have a checksum.
#       --[no-]quarantine            Disable/enable quarantining of downloads
#                                    (default: enabled).
#       --adopt                      Adopt existing artifacts in the destination
#                                    that are identical to those being installed.
#                                    Cannot be combined with --force.
#       --skip-cask-deps             Skip installing cask dependencies.
#       --zap                        For use with brew reinstall --cask. Remove
#                                    all files associated with a cask. May remove
#                                    files which are shared between applications.
#       --appdir                     Target location for Applications (default:
#                                    /Applications).
#       --keyboard-layoutdir         Target location for Keyboard Layouts
#                                    (default: /Library/Keyboard Layouts).
#       --colorpickerdir             Target location for Color Pickers (default:
#                                    ~/Library/ColorPickers).
#       --prefpanedir                Target location for Preference Panes
#                                    (default: ~/Library/PreferencePanes).
#       --qlplugindir                Target location for Quick Look Plugins
#                                    (default: ~/Library/QuickLook).
#       --mdimporterdir              Target location for Spotlight Plugins
#                                    (default: ~/Library/Spotlight).
#       --dictionarydir              Target location for Dictionaries (default:
#                                    ~/Library/Dictionaries).
#       --fontdir                    Target location for Fonts (default:
#                                    ~/Library/Fonts).
#       --servicedir                 Target location for Services (default:
#                                    ~/Library/Services).
#       --input-methoddir            Target location for Input Methods (default:
#                                    ~/Library/Input Methods).
#       --internet-plugindir         Target location for Internet Plugins
#                                    (default: ~/Library/Internet Plug-Ins).
#       --audio-unit-plugindir       Target location for Audio Unit Plugins
#                                    (default:
#                                    ~/Library/Audio/Plug-Ins/Components).
#       --vst-plugindir              Target location for VST Plugins (default:
#                                    ~/Library/Audio/Plug-Ins/VST).
#       --vst3-plugindir             Target location for VST3 Plugins (default:
#                                    ~/Library/Audio/Plug-Ins/VST3).
#       --screen-saverdir            Target location for Screen Savers (default:
#                                    ~/Library/Screen Savers).
#       --language                   Comma-separated list of language codes to
#                                    prefer for cask installation. The first
#                                    matching language is used, otherwise it
#                                    reverts to the cask's default language. The
#                                    default value is the language of your system.
#   -q, --quiet                      Make some output more quiet.
#   -h, --help                       Show this message.
# Error: invalid option: -y
# DEPRECATION: git+https://github.com/mlcommons/croissant.git@main#subdirectory=python/mlcroissant&egg=mlcroissant[dev] contains an egg fragment with a non-PEP 508 name. pip 25.1 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/13157
# Collecting mlcroissant (from mlcroissant[dev])
#   Cloning https://github.com/mlcommons/croissant.git (to revision main) to /private/var/folders/2j/2mbkhb5n5fg0fn1t37btqv140000gn/T/pip-install-r513bq3o/mlcroissant_341c4370e4a34312a172c7f1829ad51a
#   Running command git clone --filter=blob:none --quiet https://github.com/mlcommons/croissant.git /private/var/folders/2j/2mbkhb5n5fg0fn1t37btqv140000gn/T/pip-install-r513bq3o/mlcroissant_341c4370e4a34312a172c7f1829ad51a
#   Resolved https://github.com/mlcommons/croissant.git to commit de7584b0ae51464abb176b3f494c415ac360e156
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting absl-py (from mlcroissant->mlcroissant[dev])
#   Using cached absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting etils>=1.7.0 (from etils[epath]>=1.7.0->mlcroissant->mlcroissant[dev])
#   Using cached etils-1.12.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting jsonpath-rw (from mlcroissant->mlcroissant[dev])
#   Using cached jsonpath_rw-1.4.0-py3-none-any.whl
# Collecting networkx (from mlcroissant->mlcroissant[dev])
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pandas in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from mlcroissant->mlcroissant[dev]) (2.2.3)
# Collecting pandas-stubs (from mlcroissant->mlcroissant[dev])
#   Using cached pandas_stubs-2.2.3.250308-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from mlcroissant->mlcroissant[dev]) (2.9.0.post0)
# Collecting rdflib (from mlcroissant->mlcroissant[dev])
#   Using cached rdflib-7.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from mlcroissant->mlcroissant[dev]) (2.32.3)
# Requirement already satisfied: scipy in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from mlcroissant->mlcroissant[dev]) (1.15.2)
# Requirement already satisfied: tqdm in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from mlcroissant->mlcroissant[dev]) (4.67.1)
# Collecting black==23.11.0 (from mlcroissant->mlcroissant[dev])
#   Using cached black-23.11.0-py3-none-any.whl.metadata (66 kB)
# Collecting flake8-docstrings (from mlcroissant->mlcroissant[dev])
#   Using cached flake8_docstrings-1.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting mypy (from mlcroissant->mlcroissant[dev])
#   Using cached mypy-1.15.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting pyflakes (from mlcroissant->mlcroissant[dev])
#   Using cached pyflakes-3.3.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting pygraphviz (from mlcroissant->mlcroissant[dev])
#   Using cached pygraphviz-1.14.tar.gz (106 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytest (from mlcroissant->mlcroissant[dev])
#   Using cached pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting pytype (from mlcroissant->mlcroissant[dev])
#   Using cached pytype-2024.10.11-cp312-cp312-macosx_10_14_universal2.whl.metadata (10 kB)
# Collecting torchdata (from mlcroissant->mlcroissant[dev])
#   Using cached torchdata-0.11.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting click>=8.0.0 (from black==23.11.0->mlcroissant->mlcroissant[dev])
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting mypy-extensions>=0.4.3 (from black==23.11.0->mlcroissant->mlcroissant[dev])
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from black==23.11.0->mlcroissant->mlcroissant[dev]) (24.2)
# Collecting pathspec>=0.9.0 (from black==23.11.0->mlcroissant->mlcroissant[dev])
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from black==23.11.0->mlcroissant->mlcroissant[dev]) (4.3.7)
# Collecting fsspec (from etils[epath]>=1.7.0->mlcroissant->mlcroissant[dev])
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting importlib_resources (from etils[epath]>=1.7.0->mlcroissant->mlcroissant[dev])
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing_extensions in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from etils[epath]>=1.7.0->mlcroissant->mlcroissant[dev]) (4.13.0)
# Collecting zipp (from etils[epath]>=1.7.0->mlcroissant->mlcroissant[dev])
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting flake8>=3 (from flake8-docstrings->mlcroissant->mlcroissant[dev])
#   Using cached flake8-7.2.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting pydocstyle>=2.1 (from flake8-docstrings->mlcroissant->mlcroissant[dev])
#   Using cached pydocstyle-6.3.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting ply (from jsonpath-rw->mlcroissant->mlcroissant[dev])
#   Using cached ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Requirement already satisfied: decorator in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from jsonpath-rw->mlcroissant->mlcroissant[dev]) (5.2.1)
# Requirement already satisfied: six in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from jsonpath-rw->mlcroissant->mlcroissant[dev]) (1.17.0)
# Collecting librosa (from mlcroissant->mlcroissant[dev])
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting soxr==0.4.0b1 (from mlcroissant->mlcroissant[dev])
#   Using cached soxr-0.4.0b1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from soxr==0.4.0b1->mlcroissant->mlcroissant[dev]) (2.2.4)
# Collecting apache-beam (from mlcroissant->mlcroissant[dev])
#   Using cached apache_beam-2.64.0-cp312-cp312-macosx_11_0_arm64.whl
# Collecting GitPython (from mlcroissant->mlcroissant[dev])
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting Pillow (from mlcroissant->mlcroissant[dev])
#   Using cached pillow-11.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyarrow (from mlcroissant->mlcroissant[dev])
#   Using cached pyarrow-19.0.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from pandas->mlcroissant->mlcroissant[dev]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from pandas->mlcroissant->mlcroissant[dev]) (2025.2)
# Collecting types-pytz>=2022.1.1 (from pandas-stubs->mlcroissant->mlcroissant[dev])
#   Using cached types_pytz-2025.2.0.20250326-py3-none-any.whl.metadata (2.0 kB)
# Collecting iniconfig (from pytest->mlcroissant->mlcroissant[dev])
#   Using cached iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest->mlcroissant->mlcroissant[dev])
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: attrs>=21.4.0 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from pytype->mlcroissant->mlcroissant[dev]) (25.3.0)
# Collecting importlab>=0.8 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached importlab-0.8.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting immutabledict>=4.1.0 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached immutabledict-4.2.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from pytype->mlcroissant->mlcroissant[dev]) (3.1.6)
# Collecting libcst>=1.0.1 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached libcst-1.7.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (17 kB)
# Collecting msgspec>=0.18.6 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached msgspec-0.19.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.9 kB)
# Collecting ninja>=1.10.0.post2 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached ninja-1.11.1.4-py3-none-macosx_10_9_universal2.whl.metadata (5.0 kB)
# Collecting pycnite>=2024.07.31 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached pycnite-2024.7.31-py3-none-any.whl.metadata (1.3 kB)
# Collecting pydot>=1.4.2 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached pydot-3.0.4-py3-none-any.whl.metadata (10 kB)
# Collecting tabulate>=0.8.10 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting toml>=0.10.2 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting pyparsing<4,>=2.1.0 (from rdflib->mlcroissant->mlcroissant[dev])
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from requests->mlcroissant->mlcroissant[dev]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from requests->mlcroissant->mlcroissant[dev]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from requests->mlcroissant->mlcroissant[dev]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from requests->mlcroissant->mlcroissant[dev]) (2025.1.31)
# Collecting torch>=2 (from torchdata->mlcroissant->mlcroissant[dev])
#   Using cached torch-2.6.0-cp312-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8>=3->flake8-docstrings->mlcroissant->mlcroissant[dev])
#   Using cached mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pycodestyle<2.14.0,>=2.13.0 (from flake8>=3->flake8-docstrings->mlcroissant->mlcroissant[dev])
#   Using cached pycodestyle-2.13.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from jinja2>=3.1.2->pytype->mlcroissant->mlcroissant[dev]) (3.0.2)
# Requirement already satisfied: pyyaml>=5.2 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from libcst>=1.0.1->pytype->mlcroissant->mlcroissant[dev]) (6.0.2)
# Collecting snowballstemmer>=2.2.0 (from pydocstyle>=2.1->flake8-docstrings->mlcroissant->mlcroissant[dev])
#   Using cached snowballstemmer-2.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting filelock (from torch>=2->torchdata->mlcroissant->mlcroissant[dev])
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: setuptools in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from torch>=2->torchdata->mlcroissant->mlcroissant[dev]) (75.8.0)
# Collecting sympy==1.13.1 (from torch>=2->torchdata->mlcroissant->mlcroissant[dev])
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=2->torchdata->mlcroissant->mlcroissant[dev])
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting crcmod<2.0,>=1.7 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached crcmod-1.7-cp312-cp312-macosx_11_0_arm64.whl
# Collecting orjson<4,>=3.9.7 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached orjson-3.10.16-cp312-cp312-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached dill-0.3.1.1-py3-none-any.whl
# Collecting cloudpickle~=2.2.1 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting fastavro<2,>=0.23.6 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached fastavro-1.10.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (5.5 kB)
# Collecting fasteners<1.0,>=0.3 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached grpcio-1.65.5-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.3 kB)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached hdfs-2.7.3-py3-none-any.whl
# Collecting httplib2<0.23.0,>=0.8 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from apache-beam->mlcroissant->mlcroissant[dev]) (4.23.0)
# Collecting jsonpickle<4.0.0,>=3.0.0 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached jsonpickle-3.4.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting objsize<0.8.0,>=0.6.1 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached objsize-0.7.1-py3-none-any.whl.metadata (12 kB)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached pymongo-4.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (22 kB)
# Collecting proto-plus<2,>=1.7.1 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<6.0.0.dev0,>=3.20.3 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached protobuf-5.29.4-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pydot>=1.4.2 (from pytype->mlcroissant->mlcroissant[dev])
#   Using cached pydot-1.4.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting redis<6,>=5.0.0 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Collecting regex>=2020.6.8 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached regex-2024.11.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting sortedcontainers>=2.4.0 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting zstandard<1,>=0.18.0 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached zstandard-0.23.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyarrow (from mlcroissant->mlcroissant[dev])
#   Using cached pyarrow-16.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix<1 (from apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting gitdb<5,>=4.0.1 (from GitPython->mlcroissant->mlcroissant[dev])
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting audioread>=2.1.9 (from librosa->mlcroissant->mlcroissant[dev])
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numba>=0.51.0 (from librosa->mlcroissant->mlcroissant[dev])
#   Using cached numba-0.61.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting scikit-learn>=1.1.0 (from librosa->mlcroissant->mlcroissant[dev])
#   Using cached scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting joblib>=1.0 (from librosa->mlcroissant->mlcroissant[dev])
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting soundfile>=0.12.1 (from librosa->mlcroissant->mlcroissant[dev])
#   Using cached soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa->mlcroissant->mlcroissant[dev])
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting lazy_loader>=0.1 (from librosa->mlcroissant->mlcroissant[dev])
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa->mlcroissant->mlcroissant[dev])
#   Using cached msgpack-1.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython->mlcroissant->mlcroissant[dev])
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->mlcroissant->mlcroissant[dev]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->mlcroissant->mlcroissant[dev]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->mlcroissant->mlcroissant[dev]) (0.24.0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.51.0->librosa->mlcroissant->mlcroissant[dev])
#   Using cached llvmlite-0.44.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting numpy (from soxr==0.4.0b1->mlcroissant->mlcroissant[dev])
#   Using cached numpy-2.1.3-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam->mlcroissant->mlcroissant[dev])
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.1.0->librosa->mlcroissant->mlcroissant[dev])
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cffi>=1.0 in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from soundfile>=0.12.1->librosa->mlcroissant->mlcroissant[dev]) (1.17.1)
# Requirement already satisfied: pycparser in /Users/dave/miniconda3/envs/gym4real/lib/python3.12/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->mlcroissant->mlcroissant[dev]) (2.22)
# Using cached black-23.11.0-py3-none-any.whl (191 kB)
# Using cached etils-1.12.2-py3-none-any.whl (167 kB)
# Using cached absl_py-2.2.2-py3-none-any.whl (135 kB)
# Using cached flake8_docstrings-1.7.0-py2.py3-none-any.whl (5.0 kB)
# Using cached soxr-0.4.0b1-cp312-cp312-macosx_11_0_arm64.whl (388 kB)
# Using cached mypy-1.15.0-cp312-cp312-macosx_11_0_arm64.whl (9.7 MB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached pandas_stubs-2.2.3.250308-py3-none-any.whl (158 kB)
# Using cached pyflakes-3.3.2-py2.py3-none-any.whl (63 kB)
# Using cached pytest-8.3.5-py3-none-any.whl (343 kB)
# Using cached pytype-2024.10.11-cp312-cp312-macosx_10_14_universal2.whl (4.7 MB)
# Using cached rdflib-7.1.4-py3-none-any.whl (565 kB)
# Using cached torchdata-0.11.0-py3-none-any.whl (61 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached flake8-7.2.0-py2.py3-none-any.whl (57 kB)
# Using cached immutabledict-4.2.1-py3-none-any.whl (4.7 kB)
# Using cached importlab-0.8.1-py2.py3-none-any.whl (21 kB)
# Using cached libcst-1.7.0-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
# Using cached msgspec-0.19.0-cp312-cp312-macosx_11_0_arm64.whl (183 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached ninja-1.11.1.4-py3-none-macosx_10_9_universal2.whl (279 kB)
# Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached pycnite-2024.7.31-py3-none-any.whl (22 kB)
# Using cached pydocstyle-6.3.0-py3-none-any.whl (38 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached torch-2.6.0-cp312-none-macosx_11_0_arm64.whl (66.5 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached types_pytz-2025.2.0.20250326-py3-none-any.whl (10 kB)
# Using cached pyarrow-16.1.0-cp312-cp312-macosx_11_0_arm64.whl (26.0 MB)
# Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Using cached fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# Using cached pillow-11.1.0-cp312-cp312-macosx_11_0_arm64.whl (3.1 MB)
# Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Using cached fastavro-1.10.0-cp312-cp312-macosx_10_13_universal2.whl (1.0 MB)
# Using cached fasteners-0.19-py3-none-any.whl (18 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached grpcio-1.65.5-cp312-cp312-macosx_10_9_universal2.whl (10.4 MB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached jsonpickle-3.4.2-py3-none-any.whl (46 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Using cached msgpack-1.1.0-cp312-cp312-macosx_11_0_arm64.whl (82 kB)
# Using cached numba-0.61.0-cp312-cp312-macosx_11_0_arm64.whl (2.8 MB)
# Using cached numpy-2.1.3-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
# Using cached objsize-0.7.1-py3-none-any.whl (11 kB)
# Using cached orjson-3.10.16-cp312-cp312-macosx_15_0_arm64.whl (133 kB)
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached protobuf-5.29.4-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
# Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Using cached pycodestyle-2.13.0-py2.py3-none-any.whl (31 kB)
# Using cached pymongo-4.12.0-cp312-cp312-macosx_11_0_arm64.whl (909 kB)
# Using cached redis-5.2.1-py3-none-any.whl (261 kB)
# Using cached regex-2024.11.6-cp312-cp312-macosx_11_0_arm64.whl (284 kB)
# Using cached scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl (11.2 MB)
# Using cached snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
# Using cached zstandard-0.23.0-cp312-cp312-macosx_11_0_arm64.whl (633 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Using cached llvmlite-0.44.0-cp312-cp312-macosx_11_0_arm64.whl (26.2 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: mlcroissant, pygraphviz
#   Building wheel for mlcroissant (pyproject.toml) ... done
#   Created wheel for mlcroissant: filename=mlcroissant-1.0.17-py2.py3-none-any.whl size=141368 sha256=871a3a906dadfd97979d0158d1607e5db174293366edf85184c844019a80ba3b
#   Stored in directory: /private/var/folders/2j/2mbkhb5n5fg0fn1t37btqv140000gn/T/pip-ephem-wheel-cache-whn_hpi_/wheels/6d/13/b8/5d69c86bb294389dae5cc566147fa5be42a8da5e85c8d9da47
#   Building wheel for pygraphviz (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pygraphviz (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [100 lines of output]
#       /private/var/folders/2j/2mbkhb5n5fg0fn1t37btqv140000gn/T/pip-build-env-uy8_be4a/overlay/lib/python3.12/site-packages/setuptools/config/_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
#               ********************************************************************************
#               Please use a simple string containing a SPDX expression for `project.license`. You can also use `project.license-files`. (Both options available on setuptools>=77.0.0).
#
#               By 2026-Feb-18, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         corresp(dist, value, root_dir)
#       /private/var/folders/2j/2mbkhb5n5fg0fn1t37btqv140000gn/T/pip-build-env-uy8_be4a/overlay/lib/python3.12/site-packages/setuptools/config/_apply_pyprojecttoml.py:61: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: BSD License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         dist._finalize_license_expression()
#       /private/var/folders/2j/2mbkhb5n5fg0fn1t37btqv140000gn/T/pip-build-env-uy8_be4a/overlay/lib/python3.12/site-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: BSD License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-11.1-arm64-cpython-312/pygraphviz
#       copying pygraphviz/scraper.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz
#       copying pygraphviz/graphviz.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz
#       copying pygraphviz/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz
#       copying pygraphviz/agraph.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz
#       copying pygraphviz/testing.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz
#       creating build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_unicode.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_scraper.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_readwrite.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_string.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_html.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_node_attributes.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_drawing.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_repr_mimebundle.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_subgraph.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_close.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_edge_attributes.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_clear.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_layout.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_attribute_defaults.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       copying pygraphviz/tests/test_graph.py -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz/tests
#       running egg_info
#       writing pygraphviz.egg-info/PKG-INFO
#       writing dependency_links to pygraphviz.egg-info/dependency_links.txt
#       writing top-level names to pygraphviz.egg-info/top_level.txt
#       reading manifest file 'pygraphviz.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.swg'
#       warning: no files found matching '*.png' under directory 'doc'
#       warning: no files found matching '*.html' under directory 'doc'
#       warning: no files found matching '*.txt' under directory 'doc'
#       warning: no files found matching '*.css' under directory 'doc'
#       warning: no previously-included files matching '*~' found anywhere in distribution
#       warning: no previously-included files matching '*.pyc' found anywhere in distribution
#       warning: no previously-included files matching '.svn' found anywhere in distribution
#       no previously-included directories found matching 'doc/build'
#       adding license file 'LICENSE'
#       writing manifest file 'pygraphviz.egg-info/SOURCES.txt'
#       copying pygraphviz/graphviz.i -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz
#       copying pygraphviz/graphviz_wrap.c -> build/lib.macosx-11.1-arm64-cpython-312/pygraphviz
#       running build_ext
#       building 'pygraphviz._graphviz' extension
#       creating build/temp.macosx-11.1-arm64-cpython-312/pygraphviz
#       clang -fno-strict-overflow -Wsign-compare -Wunreachable-code -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /Users/dave/miniconda3/envs/gym4real/include -arch arm64 -fPIC -O2 -isystem /Users/dave/miniconda3/envs/gym4real/include -arch arm64 -DSWIG_PYTHON_STRICT_BYTE_CHAR -I/Users/dave/miniconda3/envs/gym4real/include/python3.12 -c pygraphviz/graphviz_wrap.c -o build/temp.macosx-11.1-arm64-cpython-312/pygraphviz/graphviz_wrap.o
#       pygraphviz/graphviz_wrap.c:9:9: warning: 'SWIG_PYTHON_STRICT_BYTE_CHAR' macro redefined [-Wmacro-redefined]
#           9 | #define SWIG_PYTHON_STRICT_BYTE_CHAR
#             |         ^
#       <command line>:2:9: note: previous definition is here
#           2 | #define SWIG_PYTHON_STRICT_BYTE_CHAR 1
#             |         ^
#       pygraphviz/graphviz_wrap.c:3023:10: fatal error: 'graphviz/cgraph.h' file not found
#        3023 | #include "graphviz/cgraph.h"
#             |          ^~~~~~~~~~~~~~~~~~~
#       1 warning and 1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pygraphviz
# Successfully built mlcroissant
# Failed to build pygraphviz
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (pygraphviz)

# %% [markdown]
# ## Example
#
# Let's try on a very concrete dataset: OpenAI's [`gpt-3`](https://github.com/openai/gpt-3) dataset for LLMs!
#
# In the tutorial, we will generate programmatically the Croissant JSON-LD file describing the dataset. Then we will verify the file and yield data from the dataset.

# %%
import mlcroissant as mlc

# FileObjects and FileSets define the resources of the dataset.
distribution = [
    # gpt-3 is hosted on a GitHub repository:
    mlc.FileObject(
        id="github-repository",
        name="github-repository",
        description="OpenAI repository on GitHub.",
        content_url="https://github.com/openai/gpt-3",
        encoding_formats=["git+https"],
        sha256="main",
    ),
    # Within that repository, a FileSet lists all JSONL files:
    mlc.FileSet(
        id="jsonl-files",
        name="jsonl-files",
        description="JSONL files are hosted on the GitHub repository.",
        contained_in=["github-repository"],
        encoding_formats=["application/jsonlines"],
        includes="data/*.jsonl",
    ),
]
record_sets = [
    # RecordSets contains records in the dataset.
    mlc.RecordSet(
        id="jsonl",
        name="jsonl",
        # Each record has one or many fields...
        fields=[
            # Fields can be extracted from the FileObjects/FileSets.
            mlc.Field(
                id="jsonl/context",
                name="context",
                description="",
                data_types=mlc.DataType.TEXT,
                source=mlc.Source(
                    file_set="jsonl-files",
                    # Extract the field from the column of a FileObject/FileSet:
                    extract=mlc.Extract(column="context"),
                ),
            ),
            mlc.Field(
                id="jsonl/completion",
                name="completion",
                description="The expected completion of the promt.",
                data_types=mlc.DataType.TEXT,
                source=mlc.Source(
                    file_set="jsonl-files",
                    extract=mlc.Extract(column="completion"),
                ),
            ),
            mlc.Field(
                id="jsonl/task",
                name="task",
                description=(
                    "The machine learning task appearing as the name of the"
                    " file."
                ),
                data_types=mlc.DataType.TEXT,
                source=mlc.Source(
                    file_set="jsonl-files",
                    extract=mlc.Extract(
                        file_property=mlc._src.structure_graph.nodes.source.FileProperty.filename
                    ),
                    # Extract the field from a regex on the filename:
                    transforms=[mlc.Transform(regex="^(.*)\\.jsonl$")],
                ),
            ),
        ],
    )
]

# Metadata contains information about the dataset.
metadata = mlc.Metadata(
    name="gpt-3",
    # Descriptions can contain plain text or markdown.
    description=(
        "Recent work has demonstrated substantial gains on many NLP tasks and"
        " benchmarks by pre-training on a large corpus of text followed by"
        " fine-tuning on a specific task. While typically task-agnostic in"
        " architecture, this method still requires task-specific fine-tuning"
        " datasets of thousands or tens of thousands of examples. By contrast,"
        " humans can generally perform a new language task from only a few"
        " examples or from simple instructions \u2013 something which current"
        " NLP systems still largely struggle to do. Here we show that scaling"
        " up language models greatly improves task-agnostic, few-shot"
        " performance, sometimes even reaching competitiveness with prior"
        " state-of-the-art fine-tuning approaches. Specifically, we train"
        " GPT-3, an autoregressive language model with 175 billion parameters,"
        " 10x more than any previous non-sparse language model, and test its"
        " performance in the few-shot setting. For all tasks, GPT-3 is applied"
        " without any gradient updates or fine-tuning, with tasks and few-shot"
        " demonstrations specified purely via text interaction with the model."
        " GPT-3 achieves strong performance on many NLP datasets, including"
        " translation, question-answering, and cloze tasks, as well as several"
        " tasks that require on-the-fly reasoning or domain adaptation, such as"
        " unscrambling words, using a novel word in a sentence, or performing"
        " 3-digit arithmetic. At the same time, we also identify some datasets"
        " where GPT-3's few-shot learning still struggles, as well as some"
        " datasets where GPT-3 faces methodological issues related to training"
        " on large web corpora. Finally, we find that GPT-3 can generate"
        " samples of news articles which human evaluators have difficulty"
        " distinguishing from articles written by humans. We discuss broader"
        " societal impacts of this finding and of GPT-3 in general."
    ),
    cite_as=(
        "@article{brown2020language, title={Language Models are Few-Shot"
        " Learners}, author={Tom B. Brown and Benjamin Mann and Nick Ryder and"
        " Melanie Subbiah and Jared Kaplan and Prafulla Dhariwal and Arvind"
        " Neelakantan and Pranav Shyam and Girish Sastry and Amanda Askell and"
        " Sandhini Agarwal and Ariel Herbert-Voss and Gretchen Krueger and Tom"
        " Henighan and Rewon Child and Aditya Ramesh and Daniel M. Ziegler and"
        " Jeffrey Wu and Clemens Winter and Christopher Hesse and Mark Chen and"
        " Eric Sigler and Mateusz Litwin and Scott Gray and Benjamin Chess and"
        " Jack Clark and Christopher Berner and Sam McCandlish and Alec Radford"
        " and Ilya Sutskever and Dario Amodei}, year={2020},"
        " eprint={2005.14165}, archivePrefix={arXiv}, primaryClass={cs.CL} }"
    ),
    url="https://github.com/openai/gpt-3",
    distribution=distribution,
    record_sets=record_sets,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import mlcroissant as mlc
#       3 # FileObjects and FileSets define the resources of the dataset.
#       4 distribution = [
#       5     # gpt-3 is hosted on a GitHub repository:
#       6     mlc.FileObject(
#    (...)     22     ),
#      23 ]
#
# ModuleNotFoundError: No module named 'mlcroissant'

# %% [markdown]
# When creating `Metadata`:
# - We also check for errors in the configuration.
# - We generate warnings if the configuration doesn't follow guidelines and best practices.
#
# For instance, in this case:

# %%
print(metadata.issues.report())

# %% [markdown]
# `Property "https://schema.org/license" is recommended`...
#
# We can see at a glance that we miss an important metadata to build datasets for responsible AI: the license!

# %% [markdown]
# ## Build the Croissant file and yield data
#
# Let's write the Croissant JSON-LD to a file on disk!

# %%
import json

with open("croissant.json", "w") as f:
  content = metadata.to_json()
  content = json.dumps(content, indent=2)
  print(content)
  f.write(content)
  f.write("\n")  # Terminate file with newline

# %% [markdown]
# From this JSON-LD file, we can easily create a dataset...

# %%
dataset = mlc.Dataset(jsonld="croissant.json")

# %% [markdown]
# ...and yield records from this dataset:

# %%
records = dataset.records(record_set="jsonl")

for i, record in enumerate(records):
  print(record)
  if i > 10:
    break
